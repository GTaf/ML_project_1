# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from implementations import *
from proj1_helpers import *
# %load_ext autoreload
# %autoreload 2
# Out:
# Traceback (most recent call last):
#
#   File "/Users/Darcane/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-85b6715f084f>", line 4, in <module>
#     from implementations import *
#
#   File "/Users/Darcane/Documents/EPFL/ML_project_1/implementations.py", line 65
#     print gamma
#               ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(gamma)?

# %%
def ultimate_split(yb, input_data, ids):
    """
    The ultimate split. THE real BADA$$.
    This is some real shit
    """
    
    mask_0 = (input_data[:,22] == 0)
    mask_1 = (input_data[:,22] == 1)
    mask_2 = (input_data[:,22] == 2)
    mask_3 = (input_data[:,22] == 3)
    
    return yb[mask_0], yb[mask_1], yb[mask_2], yb[mask_3], \
input_data[mask_0], input_data[mask_1], input_data[mask_2], input_data[mask_3], \
ids[mask_0], ids[mask_1], ids[mask_2], ids[mask_3]

# %%
def remove_features_0(input_data_0):
    """
    Remove the useless features if the jet num feature is equal to 0
    """
    useless_features_index = [4, 5, 6, 12, 23, 24, 25 , 26, 27, 28, 30, 33]
    
    mask = np.ones(int(input_data_0.shape[1]), dtype=bool)
    mask[(useless_features_index)] = False
    return input_data_0[:,mask]

def remove_features_1(input_data_1):
    """
    Remove the useless features if the jet num feature is equal to 1
    """
    useless_features_index = [4, 5, 6, 26, 27, 28, 30, 33]
    
    mask = np.ones(int(input_data_1.shape[1]), dtype=bool)
    mask[(useless_features_index)] = False
    return input_data_1[:,mask]

    # No need for jet_num equal to 2 or 3 : all the features are kept

# %%
def angle_features_processing(data_path):
    """
    We want to change all the features representing an angle into two features
    one for cosinus of the angle and another for sinus of the angle.
    """
    
    yb, input_data, ids = load_csv_data(data_path,sub_sample = False)

    angle_features = [15, 18, 20, 25, 28]
    
    new_data = np.zeros((input_data.shape[0], input_data.shape[1] + len(angle_features) ))
    
    for k in range(input_data.shape[1]):
        if k not in angle_features:
            new_data[:, k] = input_data[:, k]
        
    for idx, column in enumerate(angle_features): 
        
        new_data[:, column] = np.cos(input_data[:, column])
        new_data[:, input_data.shape[1] + idx] = np.sin(input_data[:, column])
    
    return yb, new_data, ids

# %%
yb, input_data, ids =  angle_features_processing("train.csv")
input_data = standardize(input_data)
yb0, yb1, yb2, yb3, data0, data1, data2, data3, ids0, ids1, ids2, ids3 = ultimate_split(yb, input_data, ids)

data0 = remove_features_0(data0)
data1 = remove_features_1(data1)
print np.shape(data0), np.shape(data1), np.shape(data2)
# Out:
# (0L, 23L) (0L, 27L) (0L, 35L)

# %%
np.std(data0)
# Out:
# 0.9999999999999987

# %%
def jet_num_split_alt(yb, input_data, ids):
    """ jet_num is feature number 22 (starting counting at 0)
    returns 1) the data with jet_num <= 1 and 2) the data with jet_num >1
    4 5 6 23 24 25 26 27"""
    bool_mask = (input_data[:,22]<=1)

    return yb[bool_mask], input_data[bool_mask], ids[bool_mask], yb[np.invert(bool_mask)], input_data[np.invert(bool_mask)], ids[np.invert(bool_mask)]

def remove_useless_features_alt(input_data_jetnum_inf1):
    useless_features_index = [4,5,6,23,24,25,26,27,28, 30, 33]
    mask = np.ones(int(input_data_jetnum_inf1.shape[1]), dtype=bool)
    # print(mask.shape)
    mask[(useless_features_index)] = False
    return input_data_jetnum_inf1[:,mask]

# %%
def jet_num_split(data_path, sub_sample = False):
    """ jet_num is feature number 22 (starting counting at 0)
        returns 1) the data with jet_num <= 1 and 2) the data with jet_num >1
        4 5 6 23 24 25 26 27"""
    yb, input_data, ids = load_csv_data(data_path,sub_sample = False)
    bool_mask = (input_data[:,22]<=1)

    return yb[bool_mask], input_data[bool_mask], ids[bool_mask], yb[np.invert(bool_mask)], input_data[np.invert(bool_mask)], ids[np.invert(bool_mask)]

def remove_useless_features(input_data_jetnum_inf1):
    useless_features_index = [4,5,6,23,24,25,26,27,28]
    mask = np.ones(int(input_data_jetnum_inf1.shape[1]), dtype=bool)
    # print(mask.shape)
    mask[(useless_features_index)] = False
    return input_data_jetnum_inf1[:,mask]

# %%
""" OLD """
yb, input_data, ids =  angle_features_processing("train.csv")

yb_inf1, input_data_inf1, ids_inf1, yb_sup1, input_data_sup1, ids_sup1 = jet_num_split_alt(yb, input_data, ids)

input_data_inf1 = remove_useless_features_alt(input_data_inf1)

# %%
""" OLD """
yb_inf1, input_data_inf1, ids_inf1, yb_sup1, input_data_sup1, ids_sup1 = jet_num_split("train.csv", sub_sample = False)
input_data_inf1 = remove_useless_features(input_data_inf1)

# %%
print(input_data_inf1.shape)
print(input_data_sup1.shape)
# Out:
# (177457, 24)
# (72543, 35)

# %%
"""sépare les données en 80/20 pour test et train
   retourne les données de train (3) puis les données de test (3)"""
def data_spliting(yb, input_data, ids):

    n = int(yb.shape[0])
    yb_test, input_data_test, ids_test = yb[:50000:], input_data[:50000:], ids[:50000:]
    yb_train, input_data_train, ids_train = yb[50000::], input_data[50000::], ids[50000::]
    return yb_train, input_data_train, ids_train, yb_test, input_data_test, ids_test

# %%
def ridge(yb_test, input_data_test, yb_train, input_data_train,lambda_):
    w, train_loss = ridge_regression(yb_train, input_data_train, lambda_)
    
    #w, train_loss = least_squares_GD_adapt_step(yb_train, input_data_train, 0*np.random.rand(int(input_data_train.shape[1])), 1000, 0.00000000001,computeLoss = True);
    
    test_loss = compute_loss(yb_test, input_data_test, w)
    y_pred = predict_labels(w, input_data_test)
    return w, train_loss, test_loss, y_pred

# %%
""" Générateur renvoyant (en k fois) des données splitées pour train et test
    Retourne les données de train puis de test"""
def K_split_LS(yb,input_data,ids,k):
    n = int(yb.shape[0])
    bool_mask = np.ones(n,dtype=bool)
    bool_mask[::k] = 0
    """On renvoie ... train puis ... test"""
    for i in range(k):
        yield yb[bool_mask], input_data[bool_mask], ids[bool_mask], yb[np.invert(bool_mask)], input_data[np.invert(bool_mask)], ids[np.invert(bool_mask)]
        bool_mask[i::k] = 1
        bool_mask[i+1::k] = 0

# %%
def Kfold_ridge(k,degree,lambda_):

    train_loss_list = []
    test_loss_list = []
    score_list = []
    for yb_train, input_data_train, ids_train, yb_test, input_data_test, ids_test in K_split_LS(yb_inf1, input_data_inf1, ids_inf1,k):
        input_data_train_poly = build_poly(input_data_train,degree)
        input_data_test_poly = build_poly(input_data_test,degree)
        w, train_loss, test_loss, y_pred = ridge(yb_test, input_data_test_poly, yb_train, input_data_train_poly,lambda_)
        train_loss_list+=[train_loss]
        test_loss_list+=[test_loss]
        score_list+=[np.mean(y_pred == yb_test)]
        
    return train_loss_list, test_loss_list,score_list

# %%
def CrossVal_ridge(k,degree,lambda_):

    yb_train, input_data_train, ids_train, yb_test, input_data_test, ids_test = data_spliting(yb, input_data, ids)
    
    input_data_train_poly = build_poly(input_data_train,degree)
    input_data_test_poly = build_poly(input_data_test,degree)
    
    w, train_loss, test_loss, y_pred = ridge(yb_test, input_data_test_poly, yb_train, input_data_train_poly,lambda_)

        
    return [train_loss], [test_loss], [np.mean(y_pred == yb_test)]

# %%
def build_poly(x, degree):
    """polynomial basis functions for input data x, for j=0 up to j=degree."""
    poly = np.ones((len(x), 1))
    for deg in range(1, degree+1):
        poly = np.c_[poly, np.power(x, deg)]
    return poly

# %%
def param_test(k,max_deg,max_lambda,lambda_step):
    lambda_list = np.arange(0,max_lambda,lambda_step)
    #lambda_list = np.logspace(1, 5, num=6)
    degree_list = np.arange(5,max_deg)
    final_train_loss_list = []
    final_test_loss_list = []
    final_score_list = []
    
    lambda_ = 1000
    
    for degree in degree_list:
        train_loss_list, test_loss_list,score_list = Kfold_ridge(k,degree,lambda_)
        #train_loss_list, test_loss_list,score_list = CrossVal_ridge(k,degree,lambda_)
        train_loss, test_loss, score = np.mean(train_loss_list), np.mean(test_loss_list), np.mean(score_list)
        final_train_loss_list+=[train_loss]
        final_test_loss_list+=[test_loss]
        final_score_list+=[score]
        print("Degree " + str(degree) + " done")
    """
    degree = 9
    for lambda_ in lambda_list:
        train_loss_list, test_loss_list,score_list = Kfold_ridge(k,degree,lambda_)
        train_loss, test_loss, score = np.mean(train_loss_list), np.mean(test_loss_list), np.mean(score_list)
        final_train_loss_list+=[train_loss]
        final_test_loss_list+=[test_loss]
        final_score_list+=[score]
        print("Lambda =  " + str(lambda_) + " done")
    """
    plt.legend()
    plt.figure(1)  
    plt.plot(degree_list,final_train_loss_list)
    plt.ylabel("Train Loss")
    plt.figure(2)
    plt.plot(degree_list,final_test_loss_list)
    plt.ylabel("Test Loss")
    plt.figure(3)
    plt.plot(degree_list,final_score_list)
    plt.ylabel("Score")
    plt.show()
    
    return final_train_loss_list, final_test_loss_list, final_score_list


def param_test_simultane(k,max_deg,max_lambda,number_lambda):
    lambda_list = np.linspace(10,max_lambda,number_lambda)
    #lambda_list = np.logspace(1, 5, num=5)
    degree_list = np.arange(4,max_deg+1)
    
    final_train_loss_list = np.zeros((len(degree_list),number_lambda))
    final_test_loss_list = np.zeros((len(degree_list),number_lambda))
    final_score_list = np.zeros((len(degree_list),number_lambda))
    """
    final_train_loss_list = np.zeros((len(degree_list),5))
    final_test_loss_list = np.zeros((len(degree_list),5))
    final_score_list = np.zeros((len(degree_list),5))
    """
    
    for j,degree in enumerate(degree_list):
        for i, lambda_ in enumerate(lambda_list):
            train_loss_list, test_loss_list,score_list = Kfold_ridge(k,degree,lambda_)
            #train_loss_list, test_loss_list,score_list = CrossVal_ridge(k,degree,lambda_)
            train_loss, test_loss, score = np.mean(train_loss_list), np.mean(test_loss_list), np.mean(score_list)
            final_train_loss_list[j,i]=train_loss
            final_test_loss_list[j,i]=test_loss
            final_score_list[j,i]=score
            print ("Degree = " + str(degree) + " and Lambda = " + str(lambda_))
    
    
    plt.legend()
    plt.figure(1)
    #plt.contourf(lambda_list,degree_list, final_train_loss_list, 20, cmap='RdGy')
    plt.pcolor(lambda_list,degree_list, final_train_loss_list)
    plt.colorbar();
    """
    plt.ylabel("Train Loss")
    plt.figure(2)
    plt.contourf(lambda_list,degree_list,  final_test_loss_list, 20, cmap='RdGy')
    plt.colorbar();
    plt.ylabel("Test Loss")
    plt.figure(3)
    plt.contourf(lambda_list,degree_list,  final_score_list, 20, cmap='RdGy')
    plt.colorbar();
    plt.ylabel("Score")
    """
    plt.show()
    
    return final_train_loss_list, final_test_loss_list, final_score_list

final_train_loss_list_inf, final_test_loss_list_inf, final_score_list_inf = param_test_simultane(10,13,1000,100)
yb_inf1, input_data_inf1, ids_inf1 = yb_sup1, input_data_sup1, ids_sup1
final_train_loss_list_sup, final_test_loss_list_sup, final_score_list_sup = param_test_simultane(10,13,1000,100)
# Out:
# Degree = 4 and Lambda = 10.0
# Degree = 4 and Lambda = 20.0
# Degree = 4 and Lambda = 30.0
# Degree = 4 and Lambda = 40.0
# Degree = 4 and Lambda = 50.0
# Degree = 4 and Lambda = 60.0
# Degree = 4 and Lambda = 70.0
# Degree = 4 and Lambda = 80.0
# Degree = 4 and Lambda = 90.0
# Degree = 4 and Lambda = 100.0
# Degree = 4 and Lambda = 110.0
# Degree = 4 and Lambda = 120.0
# Degree = 4 and Lambda = 130.0
# Degree = 4 and Lambda = 140.0
# Degree = 4 and Lambda = 150.0
# Degree = 4 and Lambda = 160.0
# Degree = 4 and Lambda = 170.0
# Degree = 4 and Lambda = 180.0
# Degree = 4 and Lambda = 190.0
# Degree = 4 and Lambda = 200.0
# Degree = 4 and Lambda = 210.0
# Degree = 4 and Lambda = 220.0
# Degree = 4 and Lambda = 230.0
# Degree = 4 and Lambda = 240.0
# Degree = 4 and Lambda = 250.0
# Degree = 4 and Lambda = 260.0
# Degree = 4 and Lambda = 270.0
# Degree = 4 and Lambda = 280.0
# Degree = 4 and Lambda = 290.0
# Degree = 4 and Lambda = 300.0
# Degree = 4 and Lambda = 310.0
# Degree = 4 and Lambda = 320.0
# Degree = 4 and Lambda = 330.0
# Degree = 4 and Lambda = 340.0
# Degree = 4 and Lambda = 350.0
# Degree = 4 and Lambda = 360.0
# Degree = 4 and Lambda = 370.0
# Degree = 4 and Lambda = 380.0
# Degree = 4 and Lambda = 390.0
# Degree = 4 and Lambda = 400.0
# Degree = 4 and Lambda = 410.0
# Degree = 4 and Lambda = 420.0
# Degree = 4 and Lambda = 430.0
# Degree = 4 and Lambda = 440.0
# Degree = 4 and Lambda = 450.0
# Degree = 4 and Lambda = 460.0
# Degree = 4 and Lambda = 470.0
# Degree = 4 and Lambda = 480.0
# Degree = 4 and Lambda = 490.0
# Degree = 4 and Lambda = 500.0
# Degree = 4 and Lambda = 510.0
# Degree = 4 and Lambda = 520.0
# Degree = 4 and Lambda = 530.0
# Degree = 4 and Lambda = 540.0
# Degree = 4 and Lambda = 550.0
# Degree = 4 and Lambda = 560.0
# Degree = 4 and Lambda = 570.0
# Degree = 4 and Lambda = 580.0
# Degree = 4 and Lambda = 590.0
# Degree = 4 and Lambda = 600.0
# Degree = 4 and Lambda = 610.0
# Degree = 4 and Lambda = 620.0
# Degree = 4 and Lambda = 630.0
# Degree = 4 and Lambda = 640.0
# Degree = 4 and Lambda = 650.0
# Degree = 4 and Lambda = 660.0
# Degree = 4 and Lambda = 670.0
# Degree = 4 and Lambda = 680.0
# Degree = 4 and Lambda = 690.0
# Degree = 4 and Lambda = 700.0
# Degree = 4 and Lambda = 710.0
# Degree = 4 and Lambda = 720.0
# Degree = 4 and Lambda = 730.0
# Degree = 4 and Lambda = 740.0
# Degree = 4 and Lambda = 750.0
# Degree = 4 and Lambda = 760.0
# Degree = 4 and Lambda = 770.0
# Degree = 4 and Lambda = 780.0
# Degree = 4 and Lambda = 790.0
# Degree = 4 and Lambda = 800.0
# Degree = 4 and Lambda = 810.0
# Degree = 4 and Lambda = 820.0
# Degree = 4 and Lambda = 830.0
# Degree = 4 and Lambda = 840.0
# Degree = 4 and Lambda = 850.0
# Degree = 4 and Lambda = 860.0
# Degree = 4 and Lambda = 870.0
# Degree = 4 and Lambda = 880.0
# Degree = 4 and Lambda = 890.0
# Degree = 4 and Lambda = 900.0
# Degree = 4 and Lambda = 910.0
# Degree = 4 and Lambda = 920.0
# Degree = 4 and Lambda = 930.0
# Degree = 4 and Lambda = 940.0
# Degree = 4 and Lambda = 950.0
# Degree = 4 and Lambda = 960.0
# Degree = 4 and Lambda = 970.0
# Degree = 4 and Lambda = 980.0
# Degree = 4 and Lambda = 990.0
# Degree = 4 and Lambda = 1000.0
# Degree = 5 and Lambda = 10.0
# Degree = 5 and Lambda = 20.0
# Degree = 5 and Lambda = 30.0
# Degree = 5 and Lambda = 40.0
# Degree = 5 and Lambda = 50.0
# Degree = 5 and Lambda = 60.0
# Degree = 5 and Lambda = 70.0
# Degree = 5 and Lambda = 80.0
# Degree = 5 and Lambda = 90.0
# Degree = 5 and Lambda = 100.0
# Degree = 5 and Lambda = 110.0
# Degree = 5 and Lambda = 120.0
# Degree = 5 and Lambda = 130.0
# Degree = 5 and Lambda = 140.0
# Degree = 5 and Lambda = 150.0
# Degree = 5 and Lambda = 160.0
# Degree = 5 and Lambda = 170.0
# Degree = 5 and Lambda = 180.0
# Degree = 5 and Lambda = 190.0
# Degree = 5 and Lambda = 200.0
# Degree = 5 and Lambda = 210.0
# Degree = 5 and Lambda = 220.0
# Degree = 5 and Lambda = 230.0
# Degree = 5 and Lambda = 240.0
# Degree = 5 and Lambda = 250.0
# Degree = 5 and Lambda = 260.0
# Degree = 5 and Lambda = 270.0
# Degree = 5 and Lambda = 280.0
# Degree = 5 and Lambda = 290.0
# Degree = 5 and Lambda = 300.0
# Degree = 5 and Lambda = 310.0
# Degree = 5 and Lambda = 320.0
# Degree = 5 and Lambda = 330.0
# Degree = 5 and Lambda = 340.0
# Degree = 5 and Lambda = 350.0
# Degree = 5 and Lambda = 360.0
# Degree = 5 and Lambda = 370.0
# Degree = 5 and Lambda = 380.0
# Degree = 5 and Lambda = 390.0
# Degree = 5 and Lambda = 400.0
# Degree = 5 and Lambda = 410.0
# Degree = 5 and Lambda = 420.0
# Degree = 5 and Lambda = 430.0
# Degree = 5 and Lambda = 440.0
# Degree = 5 and Lambda = 450.0
# Degree = 5 and Lambda = 460.0
# Degree = 5 and Lambda = 470.0
# Degree = 5 and Lambda = 480.0
# Degree = 5 and Lambda = 490.0
# Degree = 5 and Lambda = 500.0
# Degree = 5 and Lambda = 510.0
# Degree = 5 and Lambda = 520.0
# Degree = 5 and Lambda = 530.0
# Degree = 5 and Lambda = 540.0
# Degree = 5 and Lambda = 550.0
# Degree = 5 and Lambda = 560.0
# Degree = 5 and Lambda = 570.0
# Degree = 5 and Lambda = 580.0
# Degree = 5 and Lambda = 590.0
# Degree = 5 and Lambda = 600.0
# Degree = 5 and Lambda = 610.0
# Degree = 5 and Lambda = 620.0
# Degree = 5 and Lambda = 630.0
# Degree = 5 and Lambda = 640.0
# Degree = 5 and Lambda = 650.0
# Degree = 5 and Lambda = 660.0
# Degree = 5 and Lambda = 670.0
# Degree = 5 and Lambda = 680.0
# Degree = 5 and Lambda = 690.0
# Degree = 5 and Lambda = 700.0
# Degree = 5 and Lambda = 710.0
# Degree = 5 and Lambda = 720.0
# Degree = 5 and Lambda = 730.0
# Degree = 5 and Lambda = 740.0
# Degree = 5 and Lambda = 750.0
# Degree = 5 and Lambda = 760.0
# Degree = 5 and Lambda = 770.0
# Degree = 5 and Lambda = 780.0
# Degree = 5 and Lambda = 790.0
# Degree = 5 and Lambda = 800.0
# Degree = 5 and Lambda = 810.0
# Degree = 5 and Lambda = 820.0
# Degree = 5 and Lambda = 830.0
# Degree = 5 and Lambda = 840.0
# Degree = 5 and Lambda = 850.0
# Degree = 5 and Lambda = 860.0
# Degree = 5 and Lambda = 870.0
# Degree = 5 and Lambda = 880.0
# Degree = 5 and Lambda = 890.0
# Degree = 5 and Lambda = 900.0
# Degree = 5 and Lambda = 910.0
# Degree = 5 and Lambda = 920.0
# Degree = 5 and Lambda = 930.0
# Degree = 5 and Lambda = 940.0
# Degree = 5 and Lambda = 950.0
# Degree = 5 and Lambda = 960.0
# Degree = 5 and Lambda = 970.0
# Degree = 5 and Lambda = 980.0
# Degree = 5 and Lambda = 990.0
# Degree = 5 and Lambda = 1000.0
# Degree = 6 and Lambda = 10.0
# Degree = 6 and Lambda = 20.0
# Degree = 6 and Lambda = 30.0
# Degree = 6 and Lambda = 40.0
# Degree = 6 and Lambda = 50.0
# Degree = 6 and Lambda = 60.0
# Degree = 6 and Lambda = 70.0
# Degree = 6 and Lambda = 80.0
# Degree = 6 and Lambda = 90.0
# Degree = 6 and Lambda = 100.0
# Degree = 6 and Lambda = 110.0
# Degree = 6 and Lambda = 120.0
# Degree = 6 and Lambda = 130.0
# Degree = 6 and Lambda = 140.0
# Degree = 6 and Lambda = 150.0
# Degree = 6 and Lambda = 160.0
# Degree = 6 and Lambda = 170.0
# Degree = 6 and Lambda = 180.0
# Degree = 6 and Lambda = 190.0
# Degree = 6 and Lambda = 200.0
# Degree = 6 and Lambda = 210.0
# Degree = 6 and Lambda = 220.0
# Degree = 6 and Lambda = 230.0
# Degree = 6 and Lambda = 240.0
# Degree = 6 and Lambda = 250.0
# Degree = 6 and Lambda = 260.0
# Degree = 6 and Lambda = 270.0
# Degree = 6 and Lambda = 280.0
# Degree = 6 and Lambda = 290.0
# Degree = 6 and Lambda = 300.0
# Degree = 6 and Lambda = 310.0
# Degree = 6 and Lambda = 320.0
# Degree = 6 and Lambda = 330.0
# Degree = 6 and Lambda = 340.0
# Degree = 6 and Lambda = 350.0
# Degree = 6 and Lambda = 360.0
# Degree = 6 and Lambda = 370.0
# Degree = 6 and Lambda = 380.0
# Degree = 6 and Lambda = 390.0
# Degree = 6 and Lambda = 400.0
# Degree = 6 and Lambda = 410.0
# Degree = 6 and Lambda = 420.0
# Degree = 6 and Lambda = 430.0
# Degree = 6 and Lambda = 440.0
# Degree = 6 and Lambda = 450.0
# Degree = 6 and Lambda = 460.0
# Degree = 6 and Lambda = 470.0
# Degree = 6 and Lambda = 480.0
# Degree = 6 and Lambda = 490.0
# Degree = 6 and Lambda = 500.0
# Degree = 6 and Lambda = 510.0
# Degree = 6 and Lambda = 520.0
# Degree = 6 and Lambda = 530.0
# Degree = 6 and Lambda = 540.0
# Degree = 6 and Lambda = 550.0
# Degree = 6 and Lambda = 560.0
# Degree = 6 and Lambda = 570.0
# Degree = 6 and Lambda = 580.0
# Degree = 6 and Lambda = 590.0
# Degree = 6 and Lambda = 600.0
# Degree = 6 and Lambda = 610.0
# Degree = 6 and Lambda = 620.0
# Degree = 6 and Lambda = 630.0
# Degree = 6 and Lambda = 640.0
# Degree = 6 and Lambda = 650.0
# Degree = 6 and Lambda = 660.0
# Degree = 6 and Lambda = 670.0
# Degree = 6 and Lambda = 680.0
# Degree = 6 and Lambda = 690.0
# Degree = 6 and Lambda = 700.0
# Degree = 6 and Lambda = 710.0
# Degree = 6 and Lambda = 720.0
# Degree = 6 and Lambda = 730.0
# Degree = 6 and Lambda = 740.0
# Degree = 6 and Lambda = 750.0
# Degree = 6 and Lambda = 760.0
# Degree = 6 and Lambda = 770.0
# Degree = 6 and Lambda = 780.0
# Degree = 6 and Lambda = 790.0
# Degree = 6 and Lambda = 800.0
# Degree = 6 and Lambda = 810.0
# Degree = 6 and Lambda = 820.0
# Degree = 6 and Lambda = 830.0
# Degree = 6 and Lambda = 840.0
# Degree = 6 and Lambda = 850.0
# Degree = 6 and Lambda = 860.0
# Degree = 6 and Lambda = 870.0
# Degree = 6 and Lambda = 880.0
# Degree = 6 and Lambda = 890.0
# Degree = 6 and Lambda = 900.0
# Degree = 6 and Lambda = 910.0
# Degree = 6 and Lambda = 920.0
# Degree = 6 and Lambda = 930.0
# Degree = 6 and Lambda = 940.0
# Degree = 6 and Lambda = 950.0
# Degree = 6 and Lambda = 960.0
# Degree = 6 and Lambda = 970.0
# Degree = 6 and Lambda = 980.0
# Degree = 6 and Lambda = 990.0
# Degree = 6 and Lambda = 1000.0
# Degree = 7 and Lambda = 10.0
# Degree = 7 and Lambda = 20.0
# Degree = 7 and Lambda = 30.0
# Degree = 7 and Lambda = 40.0
# Degree = 7 and Lambda = 50.0
# Degree = 7 and Lambda = 60.0
# Degree = 7 and Lambda = 70.0
# Degree = 7 and Lambda = 80.0
# Degree = 7 and Lambda = 90.0
# Degree = 7 and Lambda = 100.0
# Degree = 7 and Lambda = 110.0
# Degree = 7 and Lambda = 120.0
# Degree = 7 and Lambda = 130.0
# Degree = 7 and Lambda = 140.0
# Degree = 7 and Lambda = 150.0
# Degree = 7 and Lambda = 160.0
# Degree = 7 and Lambda = 170.0
# Degree = 7 and Lambda = 180.0
# Degree = 7 and Lambda = 190.0
# Degree = 7 and Lambda = 200.0
# Degree = 7 and Lambda = 210.0
# Degree = 7 and Lambda = 220.0
# Degree = 7 and Lambda = 230.0
# Degree = 7 and Lambda = 240.0
# Degree = 7 and Lambda = 250.0
# Degree = 7 and Lambda = 260.0
# Degree = 7 and Lambda = 270.0
# Degree = 7 and Lambda = 280.0
# Degree = 7 and Lambda = 290.0
# Degree = 7 and Lambda = 300.0
# Degree = 7 and Lambda = 310.0
# Degree = 7 and Lambda = 320.0
# Degree = 7 and Lambda = 330.0
# Degree = 7 and Lambda = 340.0
# Degree = 7 and Lambda = 350.0
# Degree = 7 and Lambda = 360.0
# Degree = 7 and Lambda = 370.0
# Degree = 7 and Lambda = 380.0
# Degree = 7 and Lambda = 390.0
# Degree = 7 and Lambda = 400.0
# Degree = 7 and Lambda = 410.0
# Degree = 7 and Lambda = 420.0
# Degree = 7 and Lambda = 430.0
# Degree = 7 and Lambda = 440.0
# Degree = 7 and Lambda = 450.0
# Degree = 7 and Lambda = 460.0
# Degree = 7 and Lambda = 470.0
# Degree = 7 and Lambda = 480.0
# Degree = 7 and Lambda = 490.0
# Degree = 7 and Lambda = 500.0
# Degree = 7 and Lambda = 510.0
# Degree = 7 and Lambda = 520.0
# Degree = 7 and Lambda = 530.0
# Degree = 7 and Lambda = 540.0
# Degree = 7 and Lambda = 550.0
# Degree = 7 and Lambda = 560.0
# Degree = 7 and Lambda = 570.0
# Degree = 7 and Lambda = 580.0
# Degree = 7 and Lambda = 590.0
# Degree = 7 and Lambda = 600.0
# Degree = 7 and Lambda = 610.0
# Degree = 7 and Lambda = 620.0
# Degree = 7 and Lambda = 630.0
# Degree = 7 and Lambda = 640.0
# Degree = 7 and Lambda = 650.0
# Degree = 7 and Lambda = 660.0
# Degree = 7 and Lambda = 670.0
# Degree = 7 and Lambda = 680.0
# Degree = 7 and Lambda = 690.0
# Degree = 7 and Lambda = 700.0
# Degree = 7 and Lambda = 710.0
# Degree = 7 and Lambda = 720.0
# Degree = 7 and Lambda = 730.0
# Degree = 7 and Lambda = 740.0
# Degree = 7 and Lambda = 750.0
# Degree = 7 and Lambda = 760.0
# Degree = 7 and Lambda = 770.0
# Degree = 7 and Lambda = 780.0
# Degree = 7 and Lambda = 790.0
# Degree = 7 and Lambda = 800.0
# Degree = 7 and Lambda = 810.0
# Degree = 7 and Lambda = 820.0
# Degree = 7 and Lambda = 830.0
# Degree = 7 and Lambda = 840.0
# Degree = 7 and Lambda = 850.0
# Degree = 7 and Lambda = 860.0
# Degree = 7 and Lambda = 870.0
# Degree = 7 and Lambda = 880.0
# Degree = 7 and Lambda = 890.0
# Degree = 7 and Lambda = 900.0
# Degree = 7 and Lambda = 910.0
# Degree = 7 and Lambda = 920.0
# Degree = 7 and Lambda = 930.0
# Degree = 7 and Lambda = 940.0
# Degree = 7 and Lambda = 950.0
# Degree = 7 and Lambda = 960.0
# Degree = 7 and Lambda = 970.0
# Degree = 7 and Lambda = 980.0
# Degree = 7 and Lambda = 990.0
# Degree = 7 and Lambda = 1000.0
# Degree = 8 and Lambda = 10.0
# Degree = 8 and Lambda = 20.0
# Degree = 8 and Lambda = 30.0
# Degree = 8 and Lambda = 40.0
# Degree = 8 and Lambda = 50.0
# Degree = 8 and Lambda = 60.0
# Degree = 8 and Lambda = 70.0
# Degree = 8 and Lambda = 80.0
# Degree = 8 and Lambda = 90.0
# Degree = 8 and Lambda = 100.0
# Degree = 8 and Lambda = 110.0
# Degree = 8 and Lambda = 120.0
# Degree = 8 and Lambda = 130.0
# Degree = 8 and Lambda = 140.0
# Degree = 8 and Lambda = 150.0
# Degree = 8 and Lambda = 160.0
# Degree = 8 and Lambda = 170.0
# Degree = 8 and Lambda = 180.0
# Degree = 8 and Lambda = 190.0
# Degree = 8 and Lambda = 200.0
# Degree = 8 and Lambda = 210.0
# Degree = 8 and Lambda = 220.0
# Degree = 8 and Lambda = 230.0
# Degree = 8 and Lambda = 240.0
# Degree = 8 and Lambda = 250.0
# Degree = 8 and Lambda = 260.0
# Degree = 8 and Lambda = 270.0
# Degree = 8 and Lambda = 280.0
# Degree = 8 and Lambda = 290.0
# Degree = 8 and Lambda = 300.0
# Degree = 8 and Lambda = 310.0
# Degree = 8 and Lambda = 320.0
# Degree = 8 and Lambda = 330.0
# Degree = 8 and Lambda = 340.0
# Degree = 8 and Lambda = 350.0
# Degree = 8 and Lambda = 360.0
# Degree = 8 and Lambda = 370.0
# Degree = 8 and Lambda = 380.0
# Degree = 8 and Lambda = 390.0
# Degree = 8 and Lambda = 400.0
# Degree = 8 and Lambda = 410.0
# Degree = 8 and Lambda = 420.0
# Degree = 8 and Lambda = 430.0
# Degree = 8 and Lambda = 440.0
# Degree = 8 and Lambda = 450.0
# Degree = 8 and Lambda = 460.0
# Degree = 8 and Lambda = 470.0
# Degree = 8 and Lambda = 480.0
# Degree = 8 and Lambda = 490.0
# Degree = 8 and Lambda = 500.0
# Degree = 8 and Lambda = 510.0
# Degree = 8 and Lambda = 520.0
# Degree = 8 and Lambda = 530.0
# Degree = 8 and Lambda = 540.0
# Degree = 8 and Lambda = 550.0
# Degree = 8 and Lambda = 560.0
# Degree = 8 and Lambda = 570.0
# Degree = 8 and Lambda = 580.0
# Degree = 8 and Lambda = 590.0
# Degree = 8 and Lambda = 600.0
# Degree = 8 and Lambda = 610.0
# Degree = 8 and Lambda = 620.0
# Degree = 8 and Lambda = 630.0
# Degree = 8 and Lambda = 640.0
# Degree = 8 and Lambda = 650.0
# Degree = 8 and Lambda = 660.0
# Degree = 8 and Lambda = 670.0
# Degree = 8 and Lambda = 680.0
# Degree = 8 and Lambda = 690.0
# Degree = 8 and Lambda = 700.0
# Degree = 8 and Lambda = 710.0
# Degree = 8 and Lambda = 720.0
# Degree = 8 and Lambda = 730.0
# Degree = 8 and Lambda = 740.0
# Degree = 8 and Lambda = 750.0
# Degree = 8 and Lambda = 760.0
# Degree = 8 and Lambda = 770.0
# Degree = 8 and Lambda = 780.0
# Degree = 8 and Lambda = 790.0
# Degree = 8 and Lambda = 800.0
# Degree = 8 and Lambda = 810.0
# Degree = 8 and Lambda = 820.0
# Degree = 8 and Lambda = 830.0
# Degree = 8 and Lambda = 840.0
# Degree = 8 and Lambda = 850.0
# Degree = 8 and Lambda = 860.0
# Degree = 8 and Lambda = 870.0
# Degree = 8 and Lambda = 880.0
# Degree = 8 and Lambda = 890.0
# Degree = 8 and Lambda = 900.0
# Degree = 8 and Lambda = 910.0
# Degree = 8 and Lambda = 920.0
# Degree = 8 and Lambda = 930.0
# Degree = 8 and Lambda = 940.0
# Degree = 8 and Lambda = 950.0
# Degree = 8 and Lambda = 960.0
# Degree = 8 and Lambda = 970.0
# Degree = 8 and Lambda = 980.0
# Degree = 8 and Lambda = 990.0
# Degree = 8 and Lambda = 1000.0
# Degree = 9 and Lambda = 10.0
# Degree = 9 and Lambda = 20.0
# Degree = 9 and Lambda = 30.0
# Degree = 9 and Lambda = 40.0
# Degree = 9 and Lambda = 50.0
# Degree = 9 and Lambda = 60.0
# Degree = 9 and Lambda = 70.0
# Degree = 9 and Lambda = 80.0
# Degree = 9 and Lambda = 90.0
# Degree = 9 and Lambda = 100.0
# Degree = 9 and Lambda = 110.0
# Degree = 9 and Lambda = 120.0
# Degree = 9 and Lambda = 130.0
# Degree = 9 and Lambda = 140.0
# Degree = 9 and Lambda = 150.0
# Degree = 9 and Lambda = 160.0
# Degree = 9 and Lambda = 170.0
# Degree = 9 and Lambda = 180.0
# Degree = 9 and Lambda = 190.0
# Degree = 9 and Lambda = 200.0
# Degree = 9 and Lambda = 210.0
# Degree = 9 and Lambda = 220.0
# Degree = 9 and Lambda = 230.0
# Degree = 9 and Lambda = 240.0
# Degree = 9 and Lambda = 250.0
# Degree = 9 and Lambda = 260.0
# Degree = 9 and Lambda = 270.0
# Degree = 9 and Lambda = 280.0
# Degree = 9 and Lambda = 290.0
# Degree = 9 and Lambda = 300.0
# Degree = 9 and Lambda = 310.0
# Degree = 9 and Lambda = 320.0
# Degree = 9 and Lambda = 330.0
# Degree = 9 and Lambda = 340.0
# Degree = 9 and Lambda = 350.0
# Degree = 9 and Lambda = 360.0
# Degree = 9 and Lambda = 370.0
# Degree = 9 and Lambda = 380.0
# Degree = 9 and Lambda = 390.0
# Degree = 9 and Lambda = 400.0
# Degree = 9 and Lambda = 410.0
# Degree = 9 and Lambda = 420.0
# Degree = 9 and Lambda = 430.0
# Degree = 9 and Lambda = 440.0
# Degree = 9 and Lambda = 450.0
# Degree = 9 and Lambda = 460.0
# Degree = 9 and Lambda = 470.0
# Degree = 9 and Lambda = 480.0
# Degree = 9 and Lambda = 490.0
# Degree = 9 and Lambda = 500.0
# Degree = 9 and Lambda = 510.0
# Degree = 9 and Lambda = 520.0
# Degree = 9 and Lambda = 530.0
# Degree = 9 and Lambda = 540.0
# Degree = 9 and Lambda = 550.0
# Degree = 9 and Lambda = 560.0
# Degree = 9 and Lambda = 570.0
# Degree = 9 and Lambda = 580.0
# Degree = 9 and Lambda = 590.0
# Degree = 9 and Lambda = 600.0
# Degree = 9 and Lambda = 610.0
# Degree = 9 and Lambda = 620.0
# Degree = 9 and Lambda = 630.0
# Degree = 9 and Lambda = 640.0
# Degree = 9 and Lambda = 650.0
# Degree = 9 and Lambda = 660.0
# Degree = 9 and Lambda = 670.0
# Degree = 9 and Lambda = 680.0
# Degree = 9 and Lambda = 690.0
# Degree = 9 and Lambda = 700.0
# Degree = 9 and Lambda = 710.0
# Degree = 9 and Lambda = 720.0
# Degree = 9 and Lambda = 730.0
# Degree = 9 and Lambda = 740.0
# Degree = 9 and Lambda = 750.0
# Degree = 9 and Lambda = 760.0
# Degree = 9 and Lambda = 770.0
# Degree = 9 and Lambda = 780.0
# Degree = 9 and Lambda = 790.0
# Degree = 9 and Lambda = 800.0
# Degree = 9 and Lambda = 810.0
# Degree = 9 and Lambda = 820.0
# Degree = 9 and Lambda = 830.0
# Degree = 9 and Lambda = 840.0
# Degree = 9 and Lambda = 850.0
# Degree = 9 and Lambda = 860.0
# Degree = 9 and Lambda = 870.0
# Degree = 9 and Lambda = 880.0
# Degree = 9 and Lambda = 890.0
# Degree = 9 and Lambda = 900.0
# Degree = 9 and Lambda = 910.0
# Degree = 9 and Lambda = 920.0
# Degree = 9 and Lambda = 930.0
# Degree = 9 and Lambda = 940.0
# Degree = 9 and Lambda = 950.0
# Degree = 9 and Lambda = 960.0
# Degree = 9 and Lambda = 970.0
# Degree = 9 and Lambda = 980.0
# Degree = 9 and Lambda = 990.0
# Degree = 9 and Lambda = 1000.0
# Degree = 10 and Lambda = 10.0
# Degree = 10 and Lambda = 20.0
# Degree = 10 and Lambda = 30.0
# Degree = 10 and Lambda = 40.0
# Degree = 10 and Lambda = 50.0
# Degree = 10 and Lambda = 60.0
# Degree = 10 and Lambda = 70.0
# Degree = 10 and Lambda = 80.0
# Degree = 10 and Lambda = 90.0
# Degree = 10 and Lambda = 100.0
# Degree = 10 and Lambda = 110.0
# Degree = 10 and Lambda = 120.0
# Degree = 10 and Lambda = 130.0
# Degree = 10 and Lambda = 140.0
# Degree = 10 and Lambda = 150.0
# Degree = 10 and Lambda = 160.0
# Degree = 10 and Lambda = 170.0
# Degree = 10 and Lambda = 180.0
# Degree = 10 and Lambda = 190.0
# Degree = 10 and Lambda = 200.0
# Degree = 10 and Lambda = 210.0
# Degree = 10 and Lambda = 220.0
# Degree = 10 and Lambda = 230.0
# Degree = 10 and Lambda = 240.0
# Degree = 10 and Lambda = 250.0
# Degree = 10 and Lambda = 260.0
# Degree = 10 and Lambda = 270.0
# Degree = 10 and Lambda = 280.0
# Degree = 10 and Lambda = 290.0
# Degree = 10 and Lambda = 300.0
# Degree = 10 and Lambda = 310.0
# Degree = 10 and Lambda = 320.0
# Degree = 10 and Lambda = 330.0
# Degree = 10 and Lambda = 340.0
# Degree = 10 and Lambda = 350.0
# Degree = 10 and Lambda = 360.0
# Degree = 10 and Lambda = 370.0
# Degree = 10 and Lambda = 380.0
# Degree = 10 and Lambda = 390.0
# Degree = 10 and Lambda = 400.0
# Degree = 10 and Lambda = 410.0
# Degree = 10 and Lambda = 420.0
# Degree = 10 and Lambda = 430.0
# Degree = 10 and Lambda = 440.0
# Degree = 10 and Lambda = 450.0
# Degree = 10 and Lambda = 460.0
# Degree = 10 and Lambda = 470.0
# Degree = 10 and Lambda = 480.0
# Degree = 10 and Lambda = 490.0
# Degree = 10 and Lambda = 500.0
# Degree = 10 and Lambda = 510.0
# Degree = 10 and Lambda = 520.0
# Degree = 10 and Lambda = 530.0
# Degree = 10 and Lambda = 540.0
# Degree = 10 and Lambda = 550.0
# Degree = 10 and Lambda = 560.0
# Degree = 10 and Lambda = 570.0
# Degree = 10 and Lambda = 580.0
# Degree = 10 and Lambda = 590.0
# Degree = 10 and Lambda = 600.0
# Degree = 10 and Lambda = 610.0
# Degree = 10 and Lambda = 620.0
# Degree = 10 and Lambda = 630.0
# Degree = 10 and Lambda = 640.0
# Degree = 10 and Lambda = 650.0
# Degree = 10 and Lambda = 660.0
# Degree = 10 and Lambda = 670.0
# Degree = 10 and Lambda = 680.0
# Degree = 10 and Lambda = 690.0
# Degree = 10 and Lambda = 700.0
# Degree = 10 and Lambda = 710.0
# Degree = 10 and Lambda = 720.0
# Degree = 10 and Lambda = 730.0
# Degree = 10 and Lambda = 740.0
# Degree = 10 and Lambda = 750.0
# Degree = 10 and Lambda = 760.0
# Degree = 10 and Lambda = 770.0
# Degree = 10 and Lambda = 780.0
# Degree = 10 and Lambda = 790.0
# Degree = 10 and Lambda = 800.0
# Degree = 10 and Lambda = 810.0
# Degree = 10 and Lambda = 820.0
# Degree = 10 and Lambda = 830.0
# Degree = 10 and Lambda = 840.0
# Degree = 10 and Lambda = 850.0
# Degree = 10 and Lambda = 860.0
# Degree = 10 and Lambda = 870.0
# Degree = 10 and Lambda = 880.0
# Degree = 10 and Lambda = 890.0
# Degree = 10 and Lambda = 900.0
# Degree = 10 and Lambda = 910.0
# Degree = 10 and Lambda = 920.0
# Degree = 10 and Lambda = 930.0
# Degree = 10 and Lambda = 940.0
# Degree = 10 and Lambda = 950.0
# Degree = 10 and Lambda = 960.0
# Degree = 10 and Lambda = 970.0
# Degree = 10 and Lambda = 980.0
# Degree = 10 and Lambda = 990.0
# Degree = 10 and Lambda = 1000.0
# Degree = 11 and Lambda = 10.0
# Degree = 11 and Lambda = 20.0
# Degree = 11 and Lambda = 30.0
# Degree = 11 and Lambda = 40.0
# Degree = 11 and Lambda = 50.0
# Degree = 11 and Lambda = 60.0
# Degree = 11 and Lambda = 70.0
# Degree = 11 and Lambda = 80.0
# Degree = 11 and Lambda = 90.0
# Degree = 11 and Lambda = 100.0
# Degree = 11 and Lambda = 110.0
# Degree = 11 and Lambda = 120.0
# Degree = 11 and Lambda = 130.0
# Degree = 11 and Lambda = 140.0
# Degree = 11 and Lambda = 150.0
# Degree = 11 and Lambda = 160.0
# Degree = 11 and Lambda = 170.0
# Degree = 11 and Lambda = 180.0
# Degree = 11 and Lambda = 190.0
# Degree = 11 and Lambda = 200.0
# Degree = 11 and Lambda = 210.0
# Degree = 11 and Lambda = 220.0
# Degree = 11 and Lambda = 230.0
# Degree = 11 and Lambda = 240.0
# Degree = 11 and Lambda = 250.0
# Degree = 11 and Lambda = 260.0
# Degree = 11 and Lambda = 270.0
# Degree = 11 and Lambda = 280.0
# Degree = 11 and Lambda = 290.0
# Degree = 11 and Lambda = 300.0
# Degree = 11 and Lambda = 310.0
# Degree = 11 and Lambda = 320.0
# Degree = 11 and Lambda = 330.0
# Degree = 11 and Lambda = 340.0
# Degree = 11 and Lambda = 350.0
# Degree = 11 and Lambda = 360.0
# Degree = 11 and Lambda = 370.0
# Degree = 11 and Lambda = 380.0
# Degree = 11 and Lambda = 390.0
# Degree = 11 and Lambda = 400.0
# Degree = 11 and Lambda = 410.0
# Degree = 11 and Lambda = 420.0
# Degree = 11 and Lambda = 430.0
# Degree = 11 and Lambda = 440.0
# Degree = 11 and Lambda = 450.0
# Degree = 11 and Lambda = 460.0
# Degree = 11 and Lambda = 470.0
# Degree = 11 and Lambda = 480.0
# Degree = 11 and Lambda = 490.0
# Degree = 11 and Lambda = 500.0
# Degree = 11 and Lambda = 510.0
# Degree = 11 and Lambda = 520.0
# Degree = 11 and Lambda = 530.0
# Degree = 11 and Lambda = 540.0
# Degree = 11 and Lambda = 550.0
# Degree = 11 and Lambda = 560.0
# Degree = 11 and Lambda = 570.0
# Degree = 11 and Lambda = 580.0
# Degree = 11 and Lambda = 590.0
# Degree = 11 and Lambda = 600.0
# Degree = 11 and Lambda = 610.0
# Degree = 11 and Lambda = 620.0
# Degree = 11 and Lambda = 630.0
# Degree = 11 and Lambda = 640.0
# Degree = 11 and Lambda = 650.0
# Degree = 11 and Lambda = 660.0
# Degree = 11 and Lambda = 670.0
# Degree = 11 and Lambda = 680.0
# Degree = 11 and Lambda = 690.0
# Degree = 11 and Lambda = 700.0
# Degree = 11 and Lambda = 710.0
# Degree = 11 and Lambda = 720.0
# Degree = 11 and Lambda = 730.0
# Degree = 11 and Lambda = 740.0
# Degree = 11 and Lambda = 750.0
# Degree = 11 and Lambda = 760.0
# Degree = 11 and Lambda = 770.0
# Degree = 11 and Lambda = 780.0
# Degree = 11 and Lambda = 790.0
# Degree = 11 and Lambda = 800.0
# Degree = 11 and Lambda = 810.0
# Degree = 11 and Lambda = 820.0
# Degree = 11 and Lambda = 830.0
# Degree = 11 and Lambda = 840.0
# Degree = 11 and Lambda = 850.0
# Degree = 11 and Lambda = 860.0
# Degree = 11 and Lambda = 870.0
# Degree = 11 and Lambda = 880.0
# Degree = 11 and Lambda = 890.0
# Degree = 11 and Lambda = 900.0
# Degree = 11 and Lambda = 910.0
# Degree = 11 and Lambda = 920.0
# Degree = 11 and Lambda = 930.0
# Degree = 11 and Lambda = 940.0
# Degree = 11 and Lambda = 950.0
# Degree = 11 and Lambda = 960.0
# Degree = 11 and Lambda = 970.0
# Degree = 11 and Lambda = 980.0
# Degree = 11 and Lambda = 990.0
# Degree = 11 and Lambda = 1000.0
# Degree = 12 and Lambda = 10.0
# Degree = 12 and Lambda = 20.0
# Degree = 12 and Lambda = 30.0
# Degree = 12 and Lambda = 40.0
# Degree = 12 and Lambda = 50.0
# Degree = 12 and Lambda = 60.0
# Degree = 12 and Lambda = 70.0
# Degree = 12 and Lambda = 80.0
# Degree = 12 and Lambda = 90.0
# Degree = 12 and Lambda = 100.0
# Degree = 12 and Lambda = 110.0
# Degree = 12 and Lambda = 120.0
# Degree = 12 and Lambda = 130.0
# Degree = 12 and Lambda = 140.0
# Degree = 12 and Lambda = 150.0
# Degree = 12 and Lambda = 160.0
# Degree = 12 and Lambda = 170.0
# Degree = 12 and Lambda = 180.0
# Degree = 12 and Lambda = 190.0
# Degree = 12 and Lambda = 200.0
# Degree = 12 and Lambda = 210.0
# Degree = 12 and Lambda = 220.0
# Degree = 12 and Lambda = 230.0
# Degree = 12 and Lambda = 240.0
# Degree = 12 and Lambda = 250.0
# Degree = 12 and Lambda = 260.0
# Degree = 12 and Lambda = 270.0
# Degree = 12 and Lambda = 280.0
# Degree = 12 and Lambda = 290.0
# Degree = 12 and Lambda = 300.0
# Degree = 12 and Lambda = 310.0
# Degree = 12 and Lambda = 320.0
# Degree = 12 and Lambda = 330.0
# Degree = 12 and Lambda = 340.0
# Degree = 12 and Lambda = 350.0
# Degree = 12 and Lambda = 360.0
# Degree = 12 and Lambda = 370.0
# Degree = 12 and Lambda = 380.0
# Degree = 12 and Lambda = 390.0
# Degree = 12 and Lambda = 400.0
# Degree = 12 and Lambda = 410.0
# Degree = 12 and Lambda = 420.0
# Degree = 12 and Lambda = 430.0
# Degree = 12 and Lambda = 440.0
# Degree = 12 and Lambda = 450.0
# Degree = 12 and Lambda = 460.0
# Degree = 12 and Lambda = 470.0
# Degree = 12 and Lambda = 480.0
# Degree = 12 and Lambda = 490.0
# Degree = 12 and Lambda = 500.0
# Degree = 12 and Lambda = 510.0
# Degree = 12 and Lambda = 520.0
# Degree = 12 and Lambda = 530.0
# Degree = 12 and Lambda = 540.0
# Degree = 12 and Lambda = 550.0
# Degree = 12 and Lambda = 560.0
# Degree = 12 and Lambda = 570.0
# Degree = 12 and Lambda = 580.0
# Degree = 12 and Lambda = 590.0
# Degree = 12 and Lambda = 600.0
# Degree = 12 and Lambda = 610.0
# Degree = 12 and Lambda = 620.0
# Degree = 12 and Lambda = 630.0
# Degree = 12 and Lambda = 640.0
# Degree = 12 and Lambda = 650.0
# Degree = 12 and Lambda = 660.0
# Degree = 12 and Lambda = 670.0
# Degree = 12 and Lambda = 680.0
# Degree = 12 and Lambda = 690.0
# Degree = 12 and Lambda = 700.0
# Degree = 12 and Lambda = 710.0
# Degree = 12 and Lambda = 720.0
# Degree = 12 and Lambda = 730.0
# Degree = 12 and Lambda = 740.0
# Degree = 12 and Lambda = 750.0
# Degree = 12 and Lambda = 760.0
# Degree = 12 and Lambda = 770.0
# Degree = 12 and Lambda = 780.0
# Degree = 12 and Lambda = 790.0
# Degree = 12 and Lambda = 800.0
# Degree = 12 and Lambda = 810.0
# Degree = 12 and Lambda = 820.0
# Degree = 12 and Lambda = 830.0
# Degree = 12 and Lambda = 840.0
# Degree = 12 and Lambda = 850.0
# Degree = 12 and Lambda = 860.0
# Degree = 12 and Lambda = 870.0
# Degree = 12 and Lambda = 880.0
# Degree = 12 and Lambda = 890.0
# Degree = 12 and Lambda = 900.0
# Degree = 12 and Lambda = 910.0
# Degree = 12 and Lambda = 920.0
# Degree = 12 and Lambda = 930.0
# Degree = 12 and Lambda = 940.0
# Degree = 12 and Lambda = 950.0
# Degree = 12 and Lambda = 960.0
# Degree = 12 and Lambda = 970.0
# Degree = 12 and Lambda = 980.0
# Degree = 12 and Lambda = 990.0
# Degree = 12 and Lambda = 1000.0
# Degree = 13 and Lambda = 10.0
# Degree = 13 and Lambda = 20.0
# Degree = 13 and Lambda = 30.0
# Degree = 13 and Lambda = 40.0
# Degree = 13 and Lambda = 50.0
# Degree = 13 and Lambda = 60.0
# Degree = 13 and Lambda = 70.0
# Degree = 13 and Lambda = 80.0
# Degree = 13 and Lambda = 90.0
# Degree = 13 and Lambda = 100.0
# Degree = 13 and Lambda = 110.0
# Degree = 13 and Lambda = 120.0
# Degree = 13 and Lambda = 130.0
# Degree = 13 and Lambda = 140.0
# Degree = 13 and Lambda = 150.0
# Degree = 13 and Lambda = 160.0
# Degree = 13 and Lambda = 170.0
# Degree = 13 and Lambda = 180.0
# Degree = 13 and Lambda = 190.0
# Degree = 13 and Lambda = 200.0
# Degree = 13 and Lambda = 210.0
# Degree = 13 and Lambda = 220.0
# Degree = 13 and Lambda = 230.0
# Degree = 13 and Lambda = 240.0
# Degree = 13 and Lambda = 250.0
# Degree = 13 and Lambda = 260.0
# Degree = 13 and Lambda = 270.0
# Degree = 13 and Lambda = 280.0
# Degree = 13 and Lambda = 290.0
# Degree = 13 and Lambda = 300.0
# Degree = 13 and Lambda = 310.0
# Degree = 13 and Lambda = 320.0
# Degree = 13 and Lambda = 330.0
# Degree = 13 and Lambda = 340.0
# Degree = 13 and Lambda = 350.0
# Degree = 13 and Lambda = 360.0
# Degree = 13 and Lambda = 370.0
# Degree = 13 and Lambda = 380.0
# Degree = 13 and Lambda = 390.0
# Degree = 13 and Lambda = 400.0
# Degree = 13 and Lambda = 410.0
# Degree = 13 and Lambda = 420.0
# Degree = 13 and Lambda = 430.0
# Degree = 13 and Lambda = 440.0
# Degree = 13 and Lambda = 450.0
# Degree = 13 and Lambda = 460.0
# Degree = 13 and Lambda = 470.0
# Degree = 13 and Lambda = 480.0
# Degree = 13 and Lambda = 490.0
# Degree = 13 and Lambda = 500.0
# Degree = 13 and Lambda = 510.0
# Degree = 13 and Lambda = 520.0
# Degree = 13 and Lambda = 530.0
# Degree = 13 and Lambda = 540.0
# Degree = 13 and Lambda = 550.0
# Degree = 13 and Lambda = 560.0
# Degree = 13 and Lambda = 570.0
# Degree = 13 and Lambda = 580.0
# Degree = 13 and Lambda = 590.0
# Degree = 13 and Lambda = 600.0
# Degree = 13 and Lambda = 610.0
# Degree = 13 and Lambda = 620.0
# Degree = 13 and Lambda = 630.0
# Degree = 13 and Lambda = 640.0
# Degree = 13 and Lambda = 650.0
# Degree = 13 and Lambda = 660.0
# Degree = 13 and Lambda = 670.0
# Degree = 13 and Lambda = 680.0
# Degree = 13 and Lambda = 690.0
# Degree = 13 and Lambda = 700.0
# Degree = 13 and Lambda = 710.0
# Degree = 13 and Lambda = 720.0
# Degree = 13 and Lambda = 730.0
# Degree = 13 and Lambda = 740.0
# Degree = 13 and Lambda = 750.0
# Degree = 13 and Lambda = 760.0
# Degree = 13 and Lambda = 770.0
# Degree = 13 and Lambda = 780.0
# Degree = 13 and Lambda = 790.0
# Degree = 13 and Lambda = 800.0
# Degree = 13 and Lambda = 810.0
# Degree = 13 and Lambda = 820.0
# Degree = 13 and Lambda = 830.0
# Degree = 13 and Lambda = 840.0
# Degree = 13 and Lambda = 850.0
# Degree = 13 and Lambda = 860.0
# Degree = 13 and Lambda = 870.0
# Degree = 13 and Lambda = 880.0
# Degree = 13 and Lambda = 890.0
# Degree = 13 and Lambda = 900.0
# Degree = 13 and Lambda = 910.0
# Degree = 13 and Lambda = 920.0
# Degree = 13 and Lambda = 930.0
# Degree = 13 and Lambda = 940.0
# Degree = 13 and Lambda = 950.0
# Degree = 13 and Lambda = 960.0
# Degree = 13 and Lambda = 970.0
# Degree = 13 and Lambda = 980.0
# Degree = 13 and Lambda = 990.0
# Degree = 13 and Lambda = 1000.0
# Degree = 4 and Lambda = 10.0
# Degree = 4 and Lambda = 20.0
# Degree = 4 and Lambda = 30.0
# Degree = 4 and Lambda = 40.0
# Degree = 4 and Lambda = 50.0
# Degree = 4 and Lambda = 60.0
# Degree = 4 and Lambda = 70.0
# Degree = 4 and Lambda = 80.0
# Degree = 4 and Lambda = 90.0
# Degree = 4 and Lambda = 100.0
# Degree = 4 and Lambda = 110.0
# Degree = 4 and Lambda = 120.0
# Degree = 4 and Lambda = 130.0
# Degree = 4 and Lambda = 140.0
# Degree = 4 and Lambda = 150.0
# Degree = 4 and Lambda = 160.0
# Degree = 4 and Lambda = 170.0
# Degree = 4 and Lambda = 180.0
# Degree = 4 and Lambda = 190.0
# Degree = 4 and Lambda = 200.0
# Degree = 4 and Lambda = 210.0
# Degree = 4 and Lambda = 220.0
# Degree = 4 and Lambda = 230.0
# Degree = 4 and Lambda = 240.0
# Degree = 4 and Lambda = 250.0
# Degree = 4 and Lambda = 260.0
# Degree = 4 and Lambda = 270.0
# Degree = 4 and Lambda = 280.0
# Degree = 4 and Lambda = 290.0
# Degree = 4 and Lambda = 300.0
# Degree = 4 and Lambda = 310.0
# Degree = 4 and Lambda = 320.0
# Degree = 4 and Lambda = 330.0
# Degree = 4 and Lambda = 340.0
# Degree = 4 and Lambda = 350.0
# Degree = 4 and Lambda = 360.0
# Degree = 4 and Lambda = 370.0
# Degree = 4 and Lambda = 380.0
# Degree = 4 and Lambda = 390.0
# Degree = 4 and Lambda = 400.0
# Degree = 4 and Lambda = 410.0
# Degree = 4 and Lambda = 420.0
# Degree = 4 and Lambda = 430.0
# Degree = 4 and Lambda = 440.0
# Degree = 4 and Lambda = 450.0
# Degree = 4 and Lambda = 460.0
# Degree = 4 and Lambda = 470.0
# Degree = 4 and Lambda = 480.0
# Degree = 4 and Lambda = 490.0
# Degree = 4 and Lambda = 500.0
# Degree = 4 and Lambda = 510.0
# Degree = 4 and Lambda = 520.0
# Degree = 4 and Lambda = 530.0
# Degree = 4 and Lambda = 540.0
# Degree = 4 and Lambda = 550.0
# Degree = 4 and Lambda = 560.0
# Degree = 4 and Lambda = 570.0
# Degree = 4 and Lambda = 580.0
# Degree = 4 and Lambda = 590.0
# Degree = 4 and Lambda = 600.0
# Degree = 4 and Lambda = 610.0
# Degree = 4 and Lambda = 620.0
# Degree = 4 and Lambda = 630.0
# Degree = 4 and Lambda = 640.0
# Degree = 4 and Lambda = 650.0
# Degree = 4 and Lambda = 660.0
# Degree = 4 and Lambda = 670.0
# Degree = 4 and Lambda = 680.0
# Degree = 4 and Lambda = 690.0
# Degree = 4 and Lambda = 700.0
# Degree = 4 and Lambda = 710.0
# Degree = 4 and Lambda = 720.0
# Degree = 4 and Lambda = 730.0
# Degree = 4 and Lambda = 740.0
# Degree = 4 and Lambda = 750.0
# Degree = 4 and Lambda = 760.0
# Degree = 4 and Lambda = 770.0
# Degree = 4 and Lambda = 780.0
# Degree = 4 and Lambda = 790.0
# Degree = 4 and Lambda = 800.0
# Degree = 4 and Lambda = 810.0
# Degree = 4 and Lambda = 820.0
# Degree = 4 and Lambda = 830.0
# Degree = 4 and Lambda = 840.0
# Degree = 4 and Lambda = 850.0
# Degree = 4 and Lambda = 860.0
# Degree = 4 and Lambda = 870.0
# Degree = 4 and Lambda = 880.0
# Degree = 4 and Lambda = 890.0
# Degree = 4 and Lambda = 900.0
# Degree = 4 and Lambda = 910.0
# Degree = 4 and Lambda = 920.0
# Degree = 4 and Lambda = 930.0
# Degree = 4 and Lambda = 940.0
# Degree = 4 and Lambda = 950.0
# Degree = 4 and Lambda = 960.0
# Degree = 4 and Lambda = 970.0
# Degree = 4 and Lambda = 980.0
# Degree = 4 and Lambda = 990.0
# Degree = 4 and Lambda = 1000.0
# Degree = 5 and Lambda = 10.0
# Degree = 5 and Lambda = 20.0
# Degree = 5 and Lambda = 30.0
# Degree = 5 and Lambda = 40.0
# Degree = 5 and Lambda = 50.0
# Degree = 5 and Lambda = 60.0
# Degree = 5 and Lambda = 70.0
# Degree = 5 and Lambda = 80.0
# Degree = 5 and Lambda = 90.0
# Degree = 5 and Lambda = 100.0
# Degree = 5 and Lambda = 110.0
# Degree = 5 and Lambda = 120.0
# Degree = 5 and Lambda = 130.0
# Degree = 5 and Lambda = 140.0
# Degree = 5 and Lambda = 150.0
# Degree = 5 and Lambda = 160.0
# Degree = 5 and Lambda = 170.0
# Degree = 5 and Lambda = 180.0
# Degree = 5 and Lambda = 190.0
# Degree = 5 and Lambda = 200.0
# Degree = 5 and Lambda = 210.0
# Degree = 5 and Lambda = 220.0
# Degree = 5 and Lambda = 230.0
# Degree = 5 and Lambda = 240.0
# Degree = 5 and Lambda = 250.0
# Degree = 5 and Lambda = 260.0
# Degree = 5 and Lambda = 270.0
# Degree = 5 and Lambda = 280.0
# Degree = 5 and Lambda = 290.0
# Degree = 5 and Lambda = 300.0
# Degree = 5 and Lambda = 310.0
# Degree = 5 and Lambda = 320.0
# Degree = 5 and Lambda = 330.0
# Degree = 5 and Lambda = 340.0
# Degree = 5 and Lambda = 350.0
# Degree = 5 and Lambda = 360.0
# Degree = 5 and Lambda = 370.0
# Degree = 5 and Lambda = 380.0
# Degree = 5 and Lambda = 390.0
# Degree = 5 and Lambda = 400.0
# Degree = 5 and Lambda = 410.0
# Degree = 5 and Lambda = 420.0
# Degree = 5 and Lambda = 430.0
# Degree = 5 and Lambda = 440.0
# Degree = 5 and Lambda = 450.0
# Degree = 5 and Lambda = 460.0
# Degree = 5 and Lambda = 470.0
# Degree = 5 and Lambda = 480.0
# Degree = 5 and Lambda = 490.0
# Degree = 5 and Lambda = 500.0
# Degree = 5 and Lambda = 510.0
# Degree = 5 and Lambda = 520.0
# Degree = 5 and Lambda = 530.0
# Degree = 5 and Lambda = 540.0
# Degree = 5 and Lambda = 550.0
# Degree = 5 and Lambda = 560.0
# Degree = 5 and Lambda = 570.0
# Degree = 5 and Lambda = 580.0
# Degree = 5 and Lambda = 590.0
# Degree = 5 and Lambda = 600.0
# Degree = 5 and Lambda = 610.0
# Degree = 5 and Lambda = 620.0
# Degree = 5 and Lambda = 630.0
# Degree = 5 and Lambda = 640.0
# Degree = 5 and Lambda = 650.0
# Degree = 5 and Lambda = 660.0
# Degree = 5 and Lambda = 670.0
# Degree = 5 and Lambda = 680.0
# Degree = 5 and Lambda = 690.0
# Degree = 5 and Lambda = 700.0
# Degree = 5 and Lambda = 710.0
# Degree = 5 and Lambda = 720.0
# Degree = 5 and Lambda = 730.0
# Degree = 5 and Lambda = 740.0
# Degree = 5 and Lambda = 750.0
# Degree = 5 and Lambda = 760.0
# Degree = 5 and Lambda = 770.0
# Degree = 5 and Lambda = 780.0
# Degree = 5 and Lambda = 790.0
# Degree = 5 and Lambda = 800.0
# Degree = 5 and Lambda = 810.0
# Degree = 5 and Lambda = 820.0
# Degree = 5 and Lambda = 830.0
# Degree = 5 and Lambda = 840.0
# Degree = 5 and Lambda = 850.0
# Degree = 5 and Lambda = 860.0
# Degree = 5 and Lambda = 870.0
# Degree = 5 and Lambda = 880.0
# Degree = 5 and Lambda = 890.0
# Degree = 5 and Lambda = 900.0
# Degree = 5 and Lambda = 910.0
# Degree = 5 and Lambda = 920.0
# Degree = 5 and Lambda = 930.0
# Degree = 5 and Lambda = 940.0
# Degree = 5 and Lambda = 950.0
# Degree = 5 and Lambda = 960.0
# Degree = 5 and Lambda = 970.0
# Degree = 5 and Lambda = 980.0
# Degree = 5 and Lambda = 990.0
# Degree = 5 and Lambda = 1000.0
# Degree = 6 and Lambda = 10.0
# Degree = 6 and Lambda = 20.0
# Degree = 6 and Lambda = 30.0
# Degree = 6 and Lambda = 40.0
# Degree = 6 and Lambda = 50.0
# Degree = 6 and Lambda = 60.0
# Degree = 6 and Lambda = 70.0
# Degree = 6 and Lambda = 80.0
# Degree = 6 and Lambda = 90.0
# Degree = 6 and Lambda = 100.0
# Degree = 6 and Lambda = 110.0
# Degree = 6 and Lambda = 120.0
# Degree = 6 and Lambda = 130.0
# Degree = 6 and Lambda = 140.0
# Degree = 6 and Lambda = 150.0
# Degree = 6 and Lambda = 160.0
# Degree = 6 and Lambda = 170.0
# Degree = 6 and Lambda = 180.0
# Degree = 6 and Lambda = 190.0
# Degree = 6 and Lambda = 200.0
# Degree = 6 and Lambda = 210.0
# Degree = 6 and Lambda = 220.0
# Degree = 6 and Lambda = 230.0
# Degree = 6 and Lambda = 240.0
# Degree = 6 and Lambda = 250.0
# Degree = 6 and Lambda = 260.0
# Degree = 6 and Lambda = 270.0
# Degree = 6 and Lambda = 280.0
# Degree = 6 and Lambda = 290.0
# Degree = 6 and Lambda = 300.0
# Degree = 6 and Lambda = 310.0
# Degree = 6 and Lambda = 320.0
# Degree = 6 and Lambda = 330.0
# Degree = 6 and Lambda = 340.0
# Degree = 6 and Lambda = 350.0
# Degree = 6 and Lambda = 360.0
# Degree = 6 and Lambda = 370.0
# Degree = 6 and Lambda = 380.0
# Degree = 6 and Lambda = 390.0
# Degree = 6 and Lambda = 400.0
# Degree = 6 and Lambda = 410.0
# Degree = 6 and Lambda = 420.0
# Degree = 6 and Lambda = 430.0
# Degree = 6 and Lambda = 440.0
# Degree = 6 and Lambda = 450.0
# Degree = 6 and Lambda = 460.0
# Degree = 6 and Lambda = 470.0
# Degree = 6 and Lambda = 480.0
# Degree = 6 and Lambda = 490.0
# Degree = 6 and Lambda = 500.0
# Degree = 6 and Lambda = 510.0
# Degree = 6 and Lambda = 520.0
# Degree = 6 and Lambda = 530.0
# Degree = 6 and Lambda = 540.0
# Degree = 6 and Lambda = 550.0
# Degree = 6 and Lambda = 560.0
# Degree = 6 and Lambda = 570.0
# Degree = 6 and Lambda = 580.0
# Degree = 6 and Lambda = 590.0
# Degree = 6 and Lambda = 600.0
# Degree = 6 and Lambda = 610.0
# Degree = 6 and Lambda = 620.0
# Degree = 6 and Lambda = 630.0
# Degree = 6 and Lambda = 640.0
# Degree = 6 and Lambda = 650.0
# Degree = 6 and Lambda = 660.0
# Degree = 6 and Lambda = 670.0
# Degree = 6 and Lambda = 680.0
# Degree = 6 and Lambda = 690.0
# Degree = 6 and Lambda = 700.0
# Degree = 6 and Lambda = 710.0
# Degree = 6 and Lambda = 720.0
# Degree = 6 and Lambda = 730.0
# Degree = 6 and Lambda = 740.0
# Degree = 6 and Lambda = 750.0
# Degree = 6 and Lambda = 760.0
# Degree = 6 and Lambda = 770.0
# Degree = 6 and Lambda = 780.0
# Degree = 6 and Lambda = 790.0
# Degree = 6 and Lambda = 800.0
# Degree = 6 and Lambda = 810.0
# Degree = 6 and Lambda = 820.0
# Degree = 6 and Lambda = 830.0
# Degree = 6 and Lambda = 840.0
# Degree = 6 and Lambda = 850.0
# Degree = 6 and Lambda = 860.0
# Degree = 6 and Lambda = 870.0
# Degree = 6 and Lambda = 880.0
# Degree = 6 and Lambda = 890.0
# Degree = 6 and Lambda = 900.0
# Degree = 6 and Lambda = 910.0
# Degree = 6 and Lambda = 920.0
# Degree = 6 and Lambda = 930.0
# Degree = 6 and Lambda = 940.0
# Degree = 6 and Lambda = 950.0
# Degree = 6 and Lambda = 960.0
# Degree = 6 and Lambda = 970.0
# Degree = 6 and Lambda = 980.0
# Degree = 6 and Lambda = 990.0
# Degree = 6 and Lambda = 1000.0
# Degree = 7 and Lambda = 10.0
# Degree = 7 and Lambda = 20.0
# Degree = 7 and Lambda = 30.0
# Degree = 7 and Lambda = 40.0
# Degree = 7 and Lambda = 50.0
# Degree = 7 and Lambda = 60.0
# Degree = 7 and Lambda = 70.0
# Degree = 7 and Lambda = 80.0
# Degree = 7 and Lambda = 90.0
# Degree = 7 and Lambda = 100.0
# Degree = 7 and Lambda = 110.0
# Degree = 7 and Lambda = 120.0
# Degree = 7 and Lambda = 130.0
# Degree = 7 and Lambda = 140.0
# Degree = 7 and Lambda = 150.0
# Degree = 7 and Lambda = 160.0
# Degree = 7 and Lambda = 170.0
# Degree = 7 and Lambda = 180.0
# Degree = 7 and Lambda = 190.0
# Degree = 7 and Lambda = 200.0
# Degree = 7 and Lambda = 210.0
# Degree = 7 and Lambda = 220.0
# Degree = 7 and Lambda = 230.0
# Degree = 7 and Lambda = 240.0
# Degree = 7 and Lambda = 250.0
# Degree = 7 and Lambda = 260.0
# Degree = 7 and Lambda = 270.0
# Degree = 7 and Lambda = 280.0
# Degree = 7 and Lambda = 290.0
# Degree = 7 and Lambda = 300.0
# Degree = 7 and Lambda = 310.0
# Degree = 7 and Lambda = 320.0
# Degree = 7 and Lambda = 330.0
# Degree = 7 and Lambda = 340.0
# Degree = 7 and Lambda = 350.0
# Degree = 7 and Lambda = 360.0
# Degree = 7 and Lambda = 370.0
# Degree = 7 and Lambda = 380.0
# Degree = 7 and Lambda = 390.0
# Degree = 7 and Lambda = 400.0
# Degree = 7 and Lambda = 410.0
# Degree = 7 and Lambda = 420.0
# Degree = 7 and Lambda = 430.0
# Degree = 7 and Lambda = 440.0
# Degree = 7 and Lambda = 450.0
# Degree = 7 and Lambda = 460.0
# Degree = 7 and Lambda = 470.0
# Degree = 7 and Lambda = 480.0
# Degree = 7 and Lambda = 490.0
# Degree = 7 and Lambda = 500.0
# Degree = 7 and Lambda = 510.0
# Degree = 7 and Lambda = 520.0
# Degree = 7 and Lambda = 530.0
# Degree = 7 and Lambda = 540.0
# Degree = 7 and Lambda = 550.0
# Degree = 7 and Lambda = 560.0
# Degree = 7 and Lambda = 570.0
# Degree = 7 and Lambda = 580.0
# Degree = 7 and Lambda = 590.0
# Degree = 7 and Lambda = 600.0
# Degree = 7 and Lambda = 610.0
# Degree = 7 and Lambda = 620.0
# Degree = 7 and Lambda = 630.0
# Degree = 7 and Lambda = 640.0
# Degree = 7 and Lambda = 650.0
# Degree = 7 and Lambda = 660.0
# Degree = 7 and Lambda = 670.0
# Degree = 7 and Lambda = 680.0
# Degree = 7 and Lambda = 690.0
# Degree = 7 and Lambda = 700.0
# Degree = 7 and Lambda = 710.0
# Degree = 7 and Lambda = 720.0
# Degree = 7 and Lambda = 730.0
# Degree = 7 and Lambda = 740.0
# Degree = 7 and Lambda = 750.0
# Degree = 7 and Lambda = 760.0
# Degree = 7 and Lambda = 770.0
# Degree = 7 and Lambda = 780.0
# Degree = 7 and Lambda = 790.0
# Degree = 7 and Lambda = 800.0
# Degree = 7 and Lambda = 810.0
# Degree = 7 and Lambda = 820.0
# Degree = 7 and Lambda = 830.0
# Degree = 7 and Lambda = 840.0
# Degree = 7 and Lambda = 850.0
# Degree = 7 and Lambda = 860.0
# Degree = 7 and Lambda = 870.0
# Degree = 7 and Lambda = 880.0
# Degree = 7 and Lambda = 890.0
# Degree = 7 and Lambda = 900.0
# Degree = 7 and Lambda = 910.0
# Degree = 7 and Lambda = 920.0
# Degree = 7 and Lambda = 930.0
# Degree = 7 and Lambda = 940.0
# Degree = 7 and Lambda = 950.0
# Degree = 7 and Lambda = 960.0
# Degree = 7 and Lambda = 970.0
# Degree = 7 and Lambda = 980.0
# Degree = 7 and Lambda = 990.0
# Degree = 7 and Lambda = 1000.0
# Degree = 8 and Lambda = 10.0
# Degree = 8 and Lambda = 20.0
# Degree = 8 and Lambda = 30.0
# Degree = 8 and Lambda = 40.0
# Degree = 8 and Lambda = 50.0
# Degree = 8 and Lambda = 60.0
# Degree = 8 and Lambda = 70.0
# Degree = 8 and Lambda = 80.0
# Degree = 8 and Lambda = 90.0
# Degree = 8 and Lambda = 100.0
# Degree = 8 and Lambda = 110.0
# Degree = 8 and Lambda = 120.0
# Degree = 8 and Lambda = 130.0
# Degree = 8 and Lambda = 140.0
# Degree = 8 and Lambda = 150.0
# Degree = 8 and Lambda = 160.0
# Degree = 8 and Lambda = 170.0
# Degree = 8 and Lambda = 180.0
# Degree = 8 and Lambda = 190.0
# Degree = 8 and Lambda = 200.0
# Degree = 8 and Lambda = 210.0
# Degree = 8 and Lambda = 220.0
# Degree = 8 and Lambda = 230.0
# Degree = 8 and Lambda = 240.0
# Degree = 8 and Lambda = 250.0
# Degree = 8 and Lambda = 260.0
# Degree = 8 and Lambda = 270.0
# Degree = 8 and Lambda = 280.0
# Degree = 8 and Lambda = 290.0
# Degree = 8 and Lambda = 300.0
# Degree = 8 and Lambda = 310.0
# Degree = 8 and Lambda = 320.0
# Degree = 8 and Lambda = 330.0
# Degree = 8 and Lambda = 340.0
# Degree = 8 and Lambda = 350.0
# Degree = 8 and Lambda = 360.0
# Degree = 8 and Lambda = 370.0
# Degree = 8 and Lambda = 380.0
# Degree = 8 and Lambda = 390.0
# Degree = 8 and Lambda = 400.0
# Degree = 8 and Lambda = 410.0
# Degree = 8 and Lambda = 420.0
# Degree = 8 and Lambda = 430.0
# Degree = 8 and Lambda = 440.0
# Degree = 8 and Lambda = 450.0
# Degree = 8 and Lambda = 460.0
# Degree = 8 and Lambda = 470.0
# Degree = 8 and Lambda = 480.0
# Degree = 8 and Lambda = 490.0
# Degree = 8 and Lambda = 500.0
# Degree = 8 and Lambda = 510.0
# Degree = 8 and Lambda = 520.0
# Degree = 8 and Lambda = 530.0
# Degree = 8 and Lambda = 540.0
# Degree = 8 and Lambda = 550.0
# Degree = 8 and Lambda = 560.0
# Degree = 8 and Lambda = 570.0
# Degree = 8 and Lambda = 580.0
# Degree = 8 and Lambda = 590.0
# Degree = 8 and Lambda = 600.0
# Degree = 8 and Lambda = 610.0
# Degree = 8 and Lambda = 620.0
# Degree = 8 and Lambda = 630.0
# Degree = 8 and Lambda = 640.0
# Degree = 8 and Lambda = 650.0
# Degree = 8 and Lambda = 660.0
# Degree = 8 and Lambda = 670.0
# Degree = 8 and Lambda = 680.0
# Degree = 8 and Lambda = 690.0
# Degree = 8 and Lambda = 700.0
# Degree = 8 and Lambda = 710.0
# Degree = 8 and Lambda = 720.0
# Degree = 8 and Lambda = 730.0
# Degree = 8 and Lambda = 740.0
# Degree = 8 and Lambda = 750.0
# Degree = 8 and Lambda = 760.0
# Degree = 8 and Lambda = 770.0
# Degree = 8 and Lambda = 780.0
# Degree = 8 and Lambda = 790.0
# Degree = 8 and Lambda = 800.0
# Degree = 8 and Lambda = 810.0
# Degree = 8 and Lambda = 820.0
# Degree = 8 and Lambda = 830.0
# Degree = 8 and Lambda = 840.0
# Degree = 8 and Lambda = 850.0
# Degree = 8 and Lambda = 860.0
# Degree = 8 and Lambda = 870.0
# Degree = 8 and Lambda = 880.0
# Degree = 8 and Lambda = 890.0
# Degree = 8 and Lambda = 900.0
# Degree = 8 and Lambda = 910.0
# Degree = 8 and Lambda = 920.0
# Degree = 8 and Lambda = 930.0
# Degree = 8 and Lambda = 940.0
# Degree = 8 and Lambda = 950.0
# Degree = 8 and Lambda = 960.0
# Degree = 8 and Lambda = 970.0
# Degree = 8 and Lambda = 980.0
# Degree = 8 and Lambda = 990.0
# Degree = 8 and Lambda = 1000.0
# Degree = 9 and Lambda = 10.0
# Degree = 9 and Lambda = 20.0
# Degree = 9 and Lambda = 30.0
# Degree = 9 and Lambda = 40.0
# Degree = 9 and Lambda = 50.0
# Degree = 9 and Lambda = 60.0
# Degree = 9 and Lambda = 70.0
# Degree = 9 and Lambda = 80.0
# Degree = 9 and Lambda = 90.0
# Degree = 9 and Lambda = 100.0
# Degree = 9 and Lambda = 110.0
# Degree = 9 and Lambda = 120.0
# Degree = 9 and Lambda = 130.0
# Degree = 9 and Lambda = 140.0
# Degree = 9 and Lambda = 150.0
# Degree = 9 and Lambda = 160.0
# Degree = 9 and Lambda = 170.0
# Degree = 9 and Lambda = 180.0
# Degree = 9 and Lambda = 190.0
# Degree = 9 and Lambda = 200.0
# Degree = 9 and Lambda = 210.0
# Degree = 9 and Lambda = 220.0
# Degree = 9 and Lambda = 230.0
# Degree = 9 and Lambda = 240.0
# Degree = 9 and Lambda = 250.0
# Degree = 9 and Lambda = 260.0
# Degree = 9 and Lambda = 270.0
# Degree = 9 and Lambda = 280.0
# Degree = 9 and Lambda = 290.0
# Degree = 9 and Lambda = 300.0
# Degree = 9 and Lambda = 310.0
# Degree = 9 and Lambda = 320.0
# Degree = 9 and Lambda = 330.0
# Degree = 9 and Lambda = 340.0
# Degree = 9 and Lambda = 350.0
# Degree = 9 and Lambda = 360.0
# Degree = 9 and Lambda = 370.0
# Degree = 9 and Lambda = 380.0
# Degree = 9 and Lambda = 390.0
# Degree = 9 and Lambda = 400.0
# Degree = 9 and Lambda = 410.0
# Degree = 9 and Lambda = 420.0
# Degree = 9 and Lambda = 430.0
# Degree = 9 and Lambda = 440.0
# Degree = 9 and Lambda = 450.0
# Degree = 9 and Lambda = 460.0
# Degree = 9 and Lambda = 470.0
# Degree = 9 and Lambda = 480.0
# Degree = 9 and Lambda = 490.0
# Degree = 9 and Lambda = 500.0
# Degree = 9 and Lambda = 510.0
# Degree = 9 and Lambda = 520.0
# Degree = 9 and Lambda = 530.0
# Degree = 9 and Lambda = 540.0
# Degree = 9 and Lambda = 550.0
# Degree = 9 and Lambda = 560.0
# Degree = 9 and Lambda = 570.0
# Degree = 9 and Lambda = 580.0
# Degree = 9 and Lambda = 590.0
# Degree = 9 and Lambda = 600.0
# Degree = 9 and Lambda = 610.0
# Degree = 9 and Lambda = 620.0
# Degree = 9 and Lambda = 630.0
# Degree = 9 and Lambda = 640.0
# Degree = 9 and Lambda = 650.0
# Degree = 9 and Lambda = 660.0
# Degree = 9 and Lambda = 670.0
# Degree = 9 and Lambda = 680.0
# Degree = 9 and Lambda = 690.0
# Degree = 9 and Lambda = 700.0
# Degree = 9 and Lambda = 710.0
# Degree = 9 and Lambda = 720.0
# Degree = 9 and Lambda = 730.0
# Degree = 9 and Lambda = 740.0
# Degree = 9 and Lambda = 750.0
# Degree = 9 and Lambda = 760.0
# Degree = 9 and Lambda = 770.0
# Degree = 9 and Lambda = 780.0
# Degree = 9 and Lambda = 790.0
# Degree = 9 and Lambda = 800.0
# Degree = 9 and Lambda = 810.0
# Degree = 9 and Lambda = 820.0
# Degree = 9 and Lambda = 830.0
# Degree = 9 and Lambda = 840.0
# Degree = 9 and Lambda = 850.0
# Degree = 9 and Lambda = 860.0
# Degree = 9 and Lambda = 870.0
# Degree = 9 and Lambda = 880.0
# Degree = 9 and Lambda = 890.0
# Degree = 9 and Lambda = 900.0
# Degree = 9 and Lambda = 910.0
# Degree = 9 and Lambda = 920.0
# Degree = 9 and Lambda = 930.0
# Degree = 9 and Lambda = 940.0
# Degree = 9 and Lambda = 950.0
# Degree = 9 and Lambda = 960.0
# Degree = 9 and Lambda = 970.0
# Degree = 9 and Lambda = 980.0
# Degree = 9 and Lambda = 990.0
# Degree = 9 and Lambda = 1000.0
# Degree = 10 and Lambda = 10.0
# Degree = 10 and Lambda = 20.0
# Degree = 10 and Lambda = 30.0
# Degree = 10 and Lambda = 40.0
# Degree = 10 and Lambda = 50.0
# Degree = 10 and Lambda = 60.0
# Degree = 10 and Lambda = 70.0
# Degree = 10 and Lambda = 80.0
# Degree = 10 and Lambda = 90.0
# Degree = 10 and Lambda = 100.0
# Degree = 10 and Lambda = 110.0
# Degree = 10 and Lambda = 120.0
# Degree = 10 and Lambda = 130.0
# Degree = 10 and Lambda = 140.0
# Degree = 10 and Lambda = 150.0
# Degree = 10 and Lambda = 160.0
# Degree = 10 and Lambda = 170.0
# Degree = 10 and Lambda = 180.0
# Degree = 10 and Lambda = 190.0
# Degree = 10 and Lambda = 200.0
# Degree = 10 and Lambda = 210.0
# Degree = 10 and Lambda = 220.0
# Degree = 10 and Lambda = 230.0
# Degree = 10 and Lambda = 240.0
# Degree = 10 and Lambda = 250.0
# Degree = 10 and Lambda = 260.0
# Degree = 10 and Lambda = 270.0
# Degree = 10 and Lambda = 280.0
# Degree = 10 and Lambda = 290.0
# Degree = 10 and Lambda = 300.0
# Degree = 10 and Lambda = 310.0
# Degree = 10 and Lambda = 320.0
# Degree = 10 and Lambda = 330.0
# Degree = 10 and Lambda = 340.0
# Degree = 10 and Lambda = 350.0
# Degree = 10 and Lambda = 360.0
# Degree = 10 and Lambda = 370.0
# Degree = 10 and Lambda = 380.0
# Degree = 10 and Lambda = 390.0
# Degree = 10 and Lambda = 400.0
# Degree = 10 and Lambda = 410.0
# Degree = 10 and Lambda = 420.0
# Degree = 10 and Lambda = 430.0
# Degree = 10 and Lambda = 440.0
# Degree = 10 and Lambda = 450.0
# Degree = 10 and Lambda = 460.0
# Degree = 10 and Lambda = 470.0
# Degree = 10 and Lambda = 480.0
# Degree = 10 and Lambda = 490.0
# Degree = 10 and Lambda = 500.0
# Degree = 10 and Lambda = 510.0
# Degree = 10 and Lambda = 520.0
# Degree = 10 and Lambda = 530.0
# Degree = 10 and Lambda = 540.0
# Degree = 10 and Lambda = 550.0
# Degree = 10 and Lambda = 560.0
# Degree = 10 and Lambda = 570.0
# Degree = 10 and Lambda = 580.0
# Degree = 10 and Lambda = 590.0
# Degree = 10 and Lambda = 600.0
# Degree = 10 and Lambda = 610.0
# Degree = 10 and Lambda = 620.0
# Degree = 10 and Lambda = 630.0
# Degree = 10 and Lambda = 640.0
# Degree = 10 and Lambda = 650.0
# Degree = 10 and Lambda = 660.0
# Degree = 10 and Lambda = 670.0
# Degree = 10 and Lambda = 680.0
# Degree = 10 and Lambda = 690.0
# Degree = 10 and Lambda = 700.0
# Degree = 10 and Lambda = 710.0
# Degree = 10 and Lambda = 720.0
# Degree = 10 and Lambda = 730.0
# Degree = 10 and Lambda = 740.0
# Degree = 10 and Lambda = 750.0
# Degree = 10 and Lambda = 760.0
# Degree = 10 and Lambda = 770.0
# Degree = 10 and Lambda = 780.0
# Degree = 10 and Lambda = 790.0
# Degree = 10 and Lambda = 800.0
# Degree = 10 and Lambda = 810.0
# Degree = 10 and Lambda = 820.0
# Degree = 10 and Lambda = 830.0
# Degree = 10 and Lambda = 840.0
# Degree = 10 and Lambda = 850.0
# Degree = 10 and Lambda = 860.0
# Degree = 10 and Lambda = 870.0
# Degree = 10 and Lambda = 880.0
# Degree = 10 and Lambda = 890.0
# Degree = 10 and Lambda = 900.0
# Degree = 10 and Lambda = 910.0
# Degree = 10 and Lambda = 920.0
# Degree = 10 and Lambda = 930.0
# Degree = 10 and Lambda = 940.0
# Degree = 10 and Lambda = 950.0
# Degree = 10 and Lambda = 960.0
# Degree = 10 and Lambda = 970.0
# Degree = 10 and Lambda = 980.0
# Degree = 10 and Lambda = 990.0
# Degree = 10 and Lambda = 1000.0
# Degree = 11 and Lambda = 10.0
# Degree = 11 and Lambda = 20.0
# Degree = 11 and Lambda = 30.0
# Degree = 11 and Lambda = 40.0
# Degree = 11 and Lambda = 50.0
# Degree = 11 and Lambda = 60.0
# Degree = 11 and Lambda = 70.0
# Degree = 11 and Lambda = 80.0
# Degree = 11 and Lambda = 90.0
# Degree = 11 and Lambda = 100.0
# Degree = 11 and Lambda = 110.0
# Degree = 11 and Lambda = 120.0
# Degree = 11 and Lambda = 130.0
# Degree = 11 and Lambda = 140.0
# Degree = 11 and Lambda = 150.0
# Degree = 11 and Lambda = 160.0
# Degree = 11 and Lambda = 170.0
# Degree = 11 and Lambda = 180.0
# Degree = 11 and Lambda = 190.0
# Degree = 11 and Lambda = 200.0
# Degree = 11 and Lambda = 210.0
# Degree = 11 and Lambda = 220.0
# Degree = 11 and Lambda = 230.0
# Degree = 11 and Lambda = 240.0
# Degree = 11 and Lambda = 250.0
# Degree = 11 and Lambda = 260.0
# Degree = 11 and Lambda = 270.0
# Degree = 11 and Lambda = 280.0
# Degree = 11 and Lambda = 290.0
# Degree = 11 and Lambda = 300.0
# Degree = 11 and Lambda = 310.0
# Degree = 11 and Lambda = 320.0
# Degree = 11 and Lambda = 330.0
# Degree = 11 and Lambda = 340.0
# Degree = 11 and Lambda = 350.0
# Degree = 11 and Lambda = 360.0
# Degree = 11 and Lambda = 370.0
# Degree = 11 and Lambda = 380.0
# Degree = 11 and Lambda = 390.0
# Degree = 11 and Lambda = 400.0
# Degree = 11 and Lambda = 410.0
# Degree = 11 and Lambda = 420.0
# Degree = 11 and Lambda = 430.0
# Degree = 11 and Lambda = 440.0
# Degree = 11 and Lambda = 450.0
# Degree = 11 and Lambda = 460.0
# Degree = 11 and Lambda = 470.0
# Degree = 11 and Lambda = 480.0
# Degree = 11 and Lambda = 490.0
# Degree = 11 and Lambda = 500.0
# Degree = 11 and Lambda = 510.0
# Degree = 11 and Lambda = 520.0
# Degree = 11 and Lambda = 530.0
# Degree = 11 and Lambda = 540.0
# Degree = 11 and Lambda = 550.0
# Degree = 11 and Lambda = 560.0
# Degree = 11 and Lambda = 570.0
# Degree = 11 and Lambda = 580.0
# Degree = 11 and Lambda = 590.0
# Degree = 11 and Lambda = 600.0
# Degree = 11 and Lambda = 610.0
# Degree = 11 and Lambda = 620.0
# Degree = 11 and Lambda = 630.0
# Degree = 11 and Lambda = 640.0
# Degree = 11 and Lambda = 650.0
# Degree = 11 and Lambda = 660.0
# Degree = 11 and Lambda = 670.0
# Degree = 11 and Lambda = 680.0
# Degree = 11 and Lambda = 690.0
# Degree = 11 and Lambda = 700.0
# Degree = 11 and Lambda = 710.0
# Degree = 11 and Lambda = 720.0
# Degree = 11 and Lambda = 730.0
# Degree = 11 and Lambda = 740.0
# Degree = 11 and Lambda = 750.0
# Degree = 11 and Lambda = 760.0
# Degree = 11 and Lambda = 770.0
# Degree = 11 and Lambda = 780.0
# Degree = 11 and Lambda = 790.0
# Degree = 11 and Lambda = 800.0
# Degree = 11 and Lambda = 810.0
# Degree = 11 and Lambda = 820.0
# Degree = 11 and Lambda = 830.0
# Degree = 11 and Lambda = 840.0
# Degree = 11 and Lambda = 850.0
# Degree = 11 and Lambda = 860.0
# Degree = 11 and Lambda = 870.0
# Degree = 11 and Lambda = 880.0
# Degree = 11 and Lambda = 890.0
# Degree = 11 and Lambda = 900.0
# Degree = 11 and Lambda = 910.0
# Degree = 11 and Lambda = 920.0
# Degree = 11 and Lambda = 930.0
# Degree = 11 and Lambda = 940.0
# Degree = 11 and Lambda = 950.0
# Degree = 11 and Lambda = 960.0
# Degree = 11 and Lambda = 970.0
# Degree = 11 and Lambda = 980.0
# Degree = 11 and Lambda = 990.0
# Degree = 11 and Lambda = 1000.0
# Degree = 12 and Lambda = 10.0
# Degree = 12 and Lambda = 20.0
# Degree = 12 and Lambda = 30.0
# Degree = 12 and Lambda = 40.0
# Degree = 12 and Lambda = 50.0
# Degree = 12 and Lambda = 60.0
# Degree = 12 and Lambda = 70.0
# Degree = 12 and Lambda = 80.0
# Degree = 12 and Lambda = 90.0
# Degree = 12 and Lambda = 100.0
# Degree = 12 and Lambda = 110.0
# Degree = 12 and Lambda = 120.0
# Degree = 12 and Lambda = 130.0
# Degree = 12 and Lambda = 140.0
# Degree = 12 and Lambda = 150.0
# Degree = 12 and Lambda = 160.0
# Degree = 12 and Lambda = 170.0
# Degree = 12 and Lambda = 180.0
# Degree = 12 and Lambda = 190.0
# Degree = 12 and Lambda = 200.0
# Degree = 12 and Lambda = 210.0
# Degree = 12 and Lambda = 220.0
# Degree = 12 and Lambda = 230.0
# Degree = 12 and Lambda = 240.0
# Degree = 12 and Lambda = 250.0
# Degree = 12 and Lambda = 260.0
# Degree = 12 and Lambda = 270.0
# Degree = 12 and Lambda = 280.0
# Degree = 12 and Lambda = 290.0
# Degree = 12 and Lambda = 300.0
# Degree = 12 and Lambda = 310.0
# Degree = 12 and Lambda = 320.0
# Degree = 12 and Lambda = 330.0
# Degree = 12 and Lambda = 340.0
# Degree = 12 and Lambda = 350.0
# Degree = 12 and Lambda = 360.0
# Degree = 12 and Lambda = 370.0
# Degree = 12 and Lambda = 380.0
# Degree = 12 and Lambda = 390.0
# Degree = 12 and Lambda = 400.0
# Degree = 12 and Lambda = 410.0
# Degree = 12 and Lambda = 420.0
# Degree = 12 and Lambda = 430.0
# Degree = 12 and Lambda = 440.0
# Degree = 12 and Lambda = 450.0
# Degree = 12 and Lambda = 460.0
# Degree = 12 and Lambda = 470.0
# Degree = 12 and Lambda = 480.0
# Degree = 12 and Lambda = 490.0
# Degree = 12 and Lambda = 500.0
# Degree = 12 and Lambda = 510.0
# Degree = 12 and Lambda = 520.0
# Degree = 12 and Lambda = 530.0
# Degree = 12 and Lambda = 540.0
# Degree = 12 and Lambda = 550.0
# Degree = 12 and Lambda = 560.0
# Degree = 12 and Lambda = 570.0
# Degree = 12 and Lambda = 580.0
# Degree = 12 and Lambda = 590.0
# Degree = 12 and Lambda = 600.0
# Degree = 12 and Lambda = 610.0
# Degree = 12 and Lambda = 620.0
# Degree = 12 and Lambda = 630.0
# Degree = 12 and Lambda = 640.0
# Degree = 12 and Lambda = 650.0
# Degree = 12 and Lambda = 660.0
# Degree = 12 and Lambda = 670.0
# Degree = 12 and Lambda = 680.0
# Degree = 12 and Lambda = 690.0
# Degree = 12 and Lambda = 700.0
# Degree = 12 and Lambda = 710.0
# Degree = 12 and Lambda = 720.0
# Degree = 12 and Lambda = 730.0
# Degree = 12 and Lambda = 740.0
# Degree = 12 and Lambda = 750.0
# Degree = 12 and Lambda = 760.0
# Degree = 12 and Lambda = 770.0
# Degree = 12 and Lambda = 780.0
# Degree = 12 and Lambda = 790.0
# Degree = 12 and Lambda = 800.0
# Degree = 12 and Lambda = 810.0
# Degree = 12 and Lambda = 820.0
# Degree = 12 and Lambda = 830.0
# Degree = 12 and Lambda = 840.0
# Degree = 12 and Lambda = 850.0
# Degree = 12 and Lambda = 860.0
# Degree = 12 and Lambda = 870.0
# Degree = 12 and Lambda = 880.0
# Degree = 12 and Lambda = 890.0
# Degree = 12 and Lambda = 900.0
# Degree = 12 and Lambda = 910.0
# Degree = 12 and Lambda = 920.0
# Degree = 12 and Lambda = 930.0
# Degree = 12 and Lambda = 940.0
# Degree = 12 and Lambda = 950.0
# Degree = 12 and Lambda = 960.0
# Degree = 12 and Lambda = 970.0
# Degree = 12 and Lambda = 980.0
# Degree = 12 and Lambda = 990.0
# Degree = 12 and Lambda = 1000.0
# Degree = 13 and Lambda = 10.0
# Degree = 13 and Lambda = 20.0
# Degree = 13 and Lambda = 30.0
# Degree = 13 and Lambda = 40.0
# Degree = 13 and Lambda = 50.0
# Degree = 13 and Lambda = 60.0
# Degree = 13 and Lambda = 70.0
# Degree = 13 and Lambda = 80.0
# Degree = 13 and Lambda = 90.0
# Degree = 13 and Lambda = 100.0
# Degree = 13 and Lambda = 110.0
# Degree = 13 and Lambda = 120.0
# Degree = 13 and Lambda = 130.0
# Degree = 13 and Lambda = 140.0
# Degree = 13 and Lambda = 150.0
# Degree = 13 and Lambda = 160.0
# Degree = 13 and Lambda = 170.0
# Degree = 13 and Lambda = 180.0
# Degree = 13 and Lambda = 190.0
# Degree = 13 and Lambda = 200.0
# Degree = 13 and Lambda = 210.0
# Degree = 13 and Lambda = 220.0
# Degree = 13 and Lambda = 230.0
# Degree = 13 and Lambda = 240.0
# Degree = 13 and Lambda = 250.0
# Degree = 13 and Lambda = 260.0
# Degree = 13 and Lambda = 270.0
# Degree = 13 and Lambda = 280.0
# Degree = 13 and Lambda = 290.0
# Degree = 13 and Lambda = 300.0
# Degree = 13 and Lambda = 310.0
# Degree = 13 and Lambda = 320.0
# Degree = 13 and Lambda = 330.0
# Degree = 13 and Lambda = 340.0
# Degree = 13 and Lambda = 350.0
# Degree = 13 and Lambda = 360.0
# Degree = 13 and Lambda = 370.0
# Degree = 13 and Lambda = 380.0
# Degree = 13 and Lambda = 390.0
# Degree = 13 and Lambda = 400.0
# Degree = 13 and Lambda = 410.0
# Degree = 13 and Lambda = 420.0
# Degree = 13 and Lambda = 430.0
# Degree = 13 and Lambda = 440.0
# Degree = 13 and Lambda = 450.0
# Degree = 13 and Lambda = 460.0
# Degree = 13 and Lambda = 470.0
# Degree = 13 and Lambda = 480.0
# Degree = 13 and Lambda = 490.0
# Degree = 13 and Lambda = 500.0
# Degree = 13 and Lambda = 510.0
# Degree = 13 and Lambda = 520.0
# Degree = 13 and Lambda = 530.0
# Degree = 13 and Lambda = 540.0
# Degree = 13 and Lambda = 550.0
# Degree = 13 and Lambda = 560.0
# Degree = 13 and Lambda = 570.0
# Degree = 13 and Lambda = 580.0
# Degree = 13 and Lambda = 590.0
# Degree = 13 and Lambda = 600.0
# Degree = 13 and Lambda = 610.0
# Degree = 13 and Lambda = 620.0
# Degree = 13 and Lambda = 630.0
# Degree = 13 and Lambda = 640.0
# Degree = 13 and Lambda = 650.0
# Degree = 13 and Lambda = 660.0
# Degree = 13 and Lambda = 670.0
# Degree = 13 and Lambda = 680.0
# Degree = 13 and Lambda = 690.0
# Degree = 13 and Lambda = 700.0
# Degree = 13 and Lambda = 710.0
# Degree = 13 and Lambda = 720.0
# Degree = 13 and Lambda = 730.0
# Degree = 13 and Lambda = 740.0
# Degree = 13 and Lambda = 750.0
# Degree = 13 and Lambda = 760.0
# Degree = 13 and Lambda = 770.0
# Degree = 13 and Lambda = 780.0
# Degree = 13 and Lambda = 790.0
# Degree = 13 and Lambda = 800.0
# Degree = 13 and Lambda = 810.0
# Degree = 13 and Lambda = 820.0
# Degree = 13 and Lambda = 830.0
# Degree = 13 and Lambda = 840.0
# Degree = 13 and Lambda = 850.0
# Degree = 13 and Lambda = 860.0
# Degree = 13 and Lambda = 870.0
# Degree = 13 and Lambda = 880.0
# Degree = 13 and Lambda = 890.0
# Degree = 13 and Lambda = 900.0
# Degree = 13 and Lambda = 910.0
# Degree = 13 and Lambda = 920.0
# Degree = 13 and Lambda = 930.0
# Degree = 13 and Lambda = 940.0
# Degree = 13 and Lambda = 950.0
# Degree = 13 and Lambda = 960.0
# Degree = 13 and Lambda = 970.0
# Degree = 13 and Lambda = 980.0
# Degree = 13 and Lambda = 990.0
# Degree = 13 and Lambda = 1000.0

# %%
def submission_ridge(degree_inf1,degree_sup1,lambda_inf1,lambda_sup1):
    
    #For the inf1 data
    # yb_inf1_test, input_data_inf1_test, ids_inf1_test, yb_sup1_test, input_data_sup1_test, ids_sup1_test = jet_num_split("test.csv")
    yb_t, input_data_t, ids_t =  angle_features_processing("test.csv")

    yb_inf1_test, input_data_inf1_test, ids_inf1_test, yb_sup1_test, input_data_sup1_test, ids_sup1_test = jet_num_split_alt(yb_t, input_data_t, ids_t)

    input_data_inf1_test = remove_useless_features_alt(input_data_inf1_test)
    
    
    
    input_data_inf1_test_poly = build_poly(input_data_inf1_test, degree_inf1)
    input_data_inf1_poly = build_poly(input_data_inf1,degree_inf1)
    w, train_loss, test_loss, y_pred_inf1 = ridge(yb_inf1_test, input_data_inf1_test_poly, yb_inf1, input_data_inf1_poly,lambda_inf1)
    
    #For the sup1 data
    input_data_sup1_test_poly = build_poly(input_data_sup1_test, degree_sup1)
    input_data_sup1_poly = build_poly(input_data_sup1,degree_sup1)
    w, train_loss, test_loss, y_pred_sup1 = ridge(yb_sup1_test, input_data_sup1_test_poly, yb_sup1, input_data_sup1_poly,lambda_sup1)
    

    final_ids_test = np.concatenate((ids_inf1_test,ids_sup1_test))
    final_y_pred = np.concatenate((y_pred_inf1,y_pred_sup1))
    create_csv_submission(final_ids_test, final_y_pred, "pred_opti.csv")
    
submission_ridge(8,10,150,120)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-fd8bf01c1a93> in <module>()
#      23     create_csv_submission(final_ids_test, final_y_pred, "pred_4_210.csv")
#      24
# ---> 25 submission_ridge(8,10,150,120)
#
# <ipython-input-59-fd8bf01c1a93> in submission_ridge(degree_inf1, degree_sup1, lambda_inf1, lambda_sup1)
#      11
#      12     input_data_inf1_test_poly = build_poly(input_data_inf1_test, degree_inf1)
# ---> 13     input_data_inf1_poly = build_poly(input_data_inf1,degree_inf1)
#      14     w, train_loss, test_loss, y_pred_inf1 = ridge(yb_inf1_test, input_data_inf1_test_poly, yb_inf1, input_data_inf1_poly,lambda_inf1)
#      15
#
# NameError: global name 'input_data_inf1' is not defined

# %%
def submission_ridge_4split(deg0, deg1, deg2, deg3,lambda0, lambda1, lambda2, lambda3):
    
    #For the jet_num 0 data
    yb_t, input_data_t, ids_t =  angle_features_processing("test.csv")
    input_data_t = standardize(input_data_t)
    yb0t, yb1t, yb2t, yb3t, data0t, data1t, data2t, data3t, ids0t, ids1t, ids2t, ids3t = ultimate_split(yb_t, input_data_t, ids_t)

    data0t = remove_features_0(data0t)
    data1t = remove_features_1(data1t)
    
        
    poly_test0 = build_poly(data0t, deg0)

    poly0 = build_poly(data0,deg0)
    w, train_loss, test_loss, y_pred0 = ridge(yb0t, poly_test0, yb0, poly0,lambda0)
    
    #For the jet_num 1 data
    poly_test1 = build_poly(data1t, deg1)
    poly1 = build_poly(data1,deg1)
    w, train_loss, test_loss, y_pred1 = ridge(yb1t, poly_test1, yb1, poly1,lambda1)
    
    #For the jet_num 2 data
    poly_test2 = build_poly(data2t, deg2)
    poly2 = build_poly(data2,deg2)
    w, train_loss, test_loss, y_pred2 = ridge(yb2t, poly_test2, yb2, poly2,lambda2)

    #For the jet_num 3 data
    poly_test3 = build_poly(data3t, deg3)
    poly3 = build_poly(data3,deg3)
    w, train_loss, test_loss, y_pred3 = ridge(yb3t, poly_test3, yb3, poly3,lambda3)

    
    
    final_ids_test = np.concatenate((ids0t, ids1t, ids2t, ids3t))
    final_y_pred = np.concatenate((y_pred0,y_pred1,y_pred2,y_pred3))
    create_csv_submission(final_ids_test, final_y_pred, "pred_4split.csv")
    
submission_ridge_4split(9,9,9,9,150,150,120,120)

# %%
lambda_list = np.linspace(10,1000,100)
degree_list = np.arange(4,14)
plt.legend()
plt.figure(1)
    #plt.contourf(lambda_list,degree_list, final_train_loss_list, 20, cmap='RdGy')
plt.pcolor(lambda_list,degree_list, final_score_list_sup)
plt.colorbar()
plt.show()

# %%
"""yb_inf1, input_data_inf1, ids_inf1, yb_sup1, input_data_sup1, ids_sup1"""
#w, train_loss, test_loss, y_pred = ridge(yb_test, input_data_test, yb, input_data,0)
w, train_loss = least_squares_GD(yb, input_data, np.random.rand(int(input_data.shape[1])), 100, 0.00000001,computeLoss = True);
# Out:
# 250000
# [ 2.85456619e+05 -8.52566139e+04 -1.15462623e+05 -1.11235678e+04
#   1.72510086e+06  1.84662910e+06  1.72414230e+06 -3.84918127e+03
#  -1.55412291e+04 -7.30000083e+04 -1.98331392e+03  1.17813248e+03
#   1.72454673e+06 -4.55668042e+04  2.99605524e+01  2.51387887e+00
#  -5.77838357e+04  5.87600409e+01  1.51479330e+00 -4.04844843e+04
#  -3.64679398e+00 -1.44028727e+05  1.16997337e+02  1.17171261e+06
#   1.16772391e+06 -1.16484234e+03  1.74341139e+06  1.72441225e+06
#  -1.72654885e+03  3.03506326e+04  1.65644212e+01 -3.62399258e+01
#   1.67378394e+01 -2.81097293e+01 -4.69259330e+01]
# 250000
# [ 2.76383718e+05 -8.07973060e+04 -1.08765020e+05 -8.59514414e+03
#   1.64115554e+06  1.76089385e+06  1.64021373e+06 -3.64068130e+03
#  -1.43568755e+04 -6.49759987e+04 -1.86815470e+03  1.13673321e+03
#   1.64060873e+06 -4.26830246e+04  2.86375908e+01  2.39701430e+00
#  -5.42144171e+04  5.62829304e+01  1.47365007e+00 -3.77052123e+04
#  -3.45755281e+00 -1.31848209e+05  1.43822692e+02  1.12196093e+06
#   1.11618918e+06 -1.11341216e+03  1.65930952e+06  1.64047581e+06
#  -1.64254686e+03  3.19214441e+04  1.57345996e+01 -3.42880134e+01
#   1.60915471e+01 -2.70208177e+01 -4.46957186e+01]
# 250000
# [ 2.67731818e+05 -7.65511735e+04 -1.02388971e+05 -6.19117961e+03
#   1.56122126e+06  1.67924714e+06  1.56029546e+06 -3.44217181e+03
#  -1.32297395e+04 -5.73429914e+04 -1.75852471e+03  1.09726947e+03
#   1.56068145e+06 -3.99380833e+04  2.73774226e+01  2.28568202e+00
#  -5.08166797e+04  5.39228274e+01  1.43432724e+00 -3.50599462e+04
#  -3.27732573e+00 -1.20258447e+05  1.69303986e+02  1.07456030e+06
#   1.06709457e+06 -1.06441705e+03  1.57922508e+06  1.56055003e+06
#  -1.56255860e+03  3.34117726e+04  1.49444716e+01 -3.24296894e+01
#   1.54757065e+01 -2.59830017e+01 -4.25719903e+01]
# 250000
# [ 2.63606342e+05 -7.45296087e+04 -9.93540493e+04 -5.04845255e+03
#   1.52316393e+06  1.64037050e+06  1.52224580e+06 -3.34767390e+03
#  -1.26934144e+04 -5.37126504e+04 -1.70634238e+03  1.07845925e+03
#   1.52262748e+06 -3.86317179e+04  2.67772377e+01  2.23265013e+00
#  -4.91995539e+04  5.27984904e+01  1.41553282e+00 -3.38011173e+04
#  -3.19150421e+00 -1.14744839e+05  1.81404753e+02  1.05197946e+06
#   1.04370915e+06 -1.04107898e+03  1.54109572e+06  1.52249677e+06
#  -1.52447556e+03  3.41186224e+04  1.45683072e+01 -3.15450881e+01
#   1.51822861e+01 -2.54884241e+01 -4.15608283e+01]
# 250000
# [ 2.62263004e+05 -7.38718634e+04 -9.83667078e+04 -4.67694734e+03
#   1.51078127e+06  1.62772060e+06  1.50986563e+06 -3.31692957e+03
#  -1.25189630e+04 -5.25320816e+04 -1.68936610e+03  1.07233547e+03
#   1.51024591e+06 -3.82067543e+04  2.65819217e+01  2.21539095e+00
#  -4.86734854e+04  5.24325544e+01  1.40940566e+00 -3.33916341e+04
#  -3.16357826e+00 -1.12951609e+05  1.85336798e+02  1.04463020e+06
#   1.03609842e+06 -1.03348366e+03  1.52868953e+06  1.51011543e+06
#  -1.51208453e+03  3.43481591e+04  1.44459187e+01 -3.12572933e+01
#   1.50867808e+01 -2.53274266e+01 -4.12318215e+01]
# 250000
# [ 2.61929758e+05 -7.37087375e+04 -9.81218490e+04 -4.58483595e+03
#   1.50771026e+06  1.62458325e+06  1.50679524e+06 -3.30930490e+03
#  -1.24757019e+04 -5.22393427e+04 -1.68515602e+03  1.07081643e+03
#   1.50717517e+06 -3.81013668e+04  2.65334787e+01  2.21111016e+00
#  -4.85430236e+04  5.23417897e+01  1.40788507e+00 -3.32900870e+04
#  -3.15665218e+00 -1.12506933e+05  1.86311549e+02  1.04280733e+06
#   1.03421074e+06 -1.03159980e+03  1.52561268e+06  1.50704475e+06
#  -1.50901145e+03  3.44050487e+04  1.44155655e+01 -3.11859199e+01
#   1.50630916e+01 -2.52874914e+01 -4.11502244e+01]
# 250000
# [ 2.61863237e+05 -7.36761773e+04 -9.80729753e+04 -4.56645162e+03
#   1.50709728e+06  1.62395703e+06  1.50618239e+06 -3.30778301e+03
#  -1.24670671e+04 -5.21809142e+04 -1.68431569e+03  1.07051321e+03
#   1.50656225e+06 -3.80803317e+04  2.65238092e+01  2.21025569e+00
#  -4.85169836e+04  5.23236725e+01  1.40758150e+00 -3.32698184e+04
#  -3.15526971e+00 -1.12418178e+05  1.86506090e+02  1.04244348e+06
#   1.03383395e+06 -1.03122377e+03  1.52499853e+06  1.50643184e+06
#  -1.50839805e+03  3.44164021e+04  1.44095070e+01 -3.11716738e+01
#   1.50583631e+01 -2.52795200e+01 -4.11339374e+01]
# 250000
# [ 2.61852154e+05 -7.36707528e+04 -9.80648330e+04 -4.56338882e+03
#   1.50699516e+06  1.62385270e+06  1.50608029e+06 -3.30752946e+03
#  -1.24656286e+04 -5.21711800e+04 -1.68417569e+03  1.07046269e+03
#   1.50646013e+06 -3.80768272e+04  2.65221983e+01  2.21011334e+00
#  -4.85126454e+04  5.23206541e+01  1.40753093e+00 -3.32664417e+04
#  -3.15503939e+00 -1.12403391e+05  1.86538500e+02  1.04238286e+06
#   1.03377117e+06 -1.03116112e+03  1.52489621e+06  1.50632973e+06
#  -1.50829586e+03  3.44182935e+04  1.44084977e+01 -3.11693004e+01
#   1.50575753e+01 -2.52781919e+01 -4.11312240e+01]
# 250000
# [ 2.61850571e+05 -7.36699779e+04 -9.80636699e+04 -4.56295131e+03
#   1.50698057e+06  1.62383780e+06  1.50606570e+06 -3.30749325e+03
#  -1.24654231e+04 -5.21697895e+04 -1.68415569e+03  1.07045547e+03
#   1.50644555e+06 -3.80763266e+04  2.65219682e+01  2.21009300e+00
#  -4.85120257e+04  5.23202230e+01  1.40752370e+00 -3.32659593e+04
#  -3.15500649e+00 -1.12401279e+05  1.86543130e+02  1.04237420e+06
#   1.03376221e+06 -1.03115217e+03  1.52488160e+06  1.50631514e+06
#  -1.50828126e+03  3.44185637e+04  1.44083535e+01 -3.11689613e+01
#   1.50574628e+01 -2.52780022e+01 -4.11308364e+01]
# 250000
# [ 2.61850373e+05 -7.36698810e+04 -9.80635245e+04 -4.56289662e+03
#   1.50697875e+06  1.62383593e+06  1.50606388e+06 -3.30748872e+03
#  -1.24653974e+04 -5.21696157e+04 -1.68415319e+03  1.07045457e+03
#   1.50644372e+06 -3.80762640e+04  2.65219394e+01  2.21009046e+00
#  -4.85119482e+04  5.23201691e+01  1.40752280e+00 -3.32658990e+04
#  -3.15500238e+00 -1.12401015e+05  1.86543708e+02  1.04237312e+06
#   1.03376108e+06 -1.03115105e+03  1.52487977e+06  1.50631332e+06
#  -1.50827944e+03  3.44185975e+04  1.44083355e+01 -3.11689190e+01
#   1.50574487e+01 -2.52779785e+01 -4.11307879e+01]
# 250000
# [ 2.61850351e+05 -7.36698703e+04 -9.80635083e+04 -4.56289055e+03
#   1.50697855e+06  1.62383573e+06  1.50606368e+06 -3.30748822e+03
#  -1.24653945e+04 -5.21695964e+04 -1.68415291e+03  1.07045447e+03
#   1.50644352e+06 -3.80762571e+04  2.65219362e+01  2.21009018e+00
#  -4.85119396e+04  5.23201631e+01  1.40752270e+00 -3.32658923e+04
#  -3.15500192e+00 -1.12400986e+05  1.86543773e+02  1.04237300e+06
#   1.03376096e+06 -1.03115093e+03  1.52487957e+06  1.50631312e+06
#  -1.50827924e+03  3.44186012e+04  1.44083335e+01 -3.11689143e+01
#   1.50574472e+01 -2.52779758e+01 -4.11307826e+01]
# 250000
# [ 2.61850349e+05 -7.36698692e+04 -9.80635067e+04 -4.56288994e+03
#   1.50697852e+06  1.62383571e+06  1.50606366e+06 -3.30748817e+03
#  -1.24653942e+04 -5.21695945e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762564e+04  2.65219359e+01  2.21009015e+00
#  -4.85119387e+04  5.23201625e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500188e+00 -1.12400983e+05  1.86543779e+02  1.04237299e+06
#   1.03376095e+06 -1.03115092e+03  1.52487955e+06  1.50631310e+06
#  -1.50827922e+03  3.44186016e+04  1.44083333e+01 -3.11689138e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635066e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119387e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115092e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115092e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]
# 250000
# [ 2.61850349e+05 -7.36698691e+04 -9.80635065e+04 -4.56288988e+03
#   1.50697852e+06  1.62383571e+06  1.50606365e+06 -3.30748816e+03
#  -1.24653942e+04 -5.21695943e+04 -1.68415288e+03  1.07045446e+03
#   1.50644350e+06 -3.80762563e+04  2.65219359e+01  2.21009015e+00
#  -4.85119386e+04  5.23201624e+01  1.40752269e+00 -3.32658916e+04
#  -3.15500187e+00 -1.12400983e+05  1.86543780e+02  1.04237298e+06
#   1.03376095e+06 -1.03115091e+03  1.52487955e+06  1.50631309e+06
#  -1.50827921e+03  3.44186017e+04  1.44083332e+01 -3.11689137e+01
#   1.50574470e+01 -2.52779756e+01 -4.11307820e+01]

# %%
np.argmax(final_score_list_inf)
# Out:
# 603

# %%
final_score_list_sup[5,0]
# Out:
# 0.8142894065243501
